# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Installing citipy module
#!pip install citipy
from citipy import citipy

# Dependencies
import pandas as pd
import numpy as np
import requests
import json

from scipy import stats
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Google API Key
from api_keys import g_key
from api_keys import weather_api_key
from itertools import product
from itertools import permutations
# print (weather_api_key)

import scipy.stats as st

# %% [markdown]
# ## Generate Cities List

# %%
#**********Need to fix the limit, gives more than 500 values***************

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1600)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1600)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %%
cities
# Out:
# ['jorochito',
#  'ushuaia',
#  'yellowknife',
#  'cherskiy',
#  'rock sound',
#  'sfantu gheorghe',
#  'santa isabel do rio negro',
#  'camacha',
#  'chapais',
#  'caravelas',
#  'yeniseysk',
#  'mataura',
#  'ogulin',
#  'atuona',
#  'mrirt',
#  'jacareacanga',
#  'ballina',
#  'malwan',
#  'labuhan',
#  'punta arenas',
#  'ust-barguzin',
#  'rikitea',
#  'hermanus',
#  'maamba',
#  'sitka',
#  'rjukan',
#  'arys',
#  'barrow',
#  'noyabrsk',
#  'butaritari',
#  'verkhnyaya inta',
#  'mar del plata',
#  'puerto ayora',
#  'hobart',
#  'bluff',
#  'saint-philippe',
#  'ahuimanu',
#  'christchurch',
#  'saskylakh',
#  'todos santos',
#  'raga',
#  'thompson',
#  'port elizabeth',
#  'avarua',
#  'lalmohan',
#  'cape town',
#  'san jeronimo',
#  'haibowan',
#  'georgetown',
#  'kavieng',
#  'paamiut',
#  'numan',
#  'lufilufi',
#  'margate',
#  'nkoteng',
#  'esperance',
#  'datong',
#  'hilo',
#  'tuktoyaktuk',
#  'duluth',
#  'dingle',
#  'arraial do cabo',
#  'coquimbo',
#  'bredasdorp',
#  'ostrovnoy',
#  'vila do maio',
#  'noumea',
#  'kuybysheve',
#  'soyo',
#  'martapura',
#  'lieksa',
#  'kapaa',
#  'soltsy',
#  'ngawen',
#  'east london',
#  'dalvik',
#  'pangai',
#  'namtsy',
#  'longjiang',
#  'ribeira grande',
#  'mahebourg',
#  'new norfolk',
#  'san patricio',
#  'lagoa',
#  'xining',
#  'batagay-alyta',
#  'sobolevo',
#  'dombarovskiy',
#  'lebu',
#  'nizhneyansk',
#  'port blair',
#  'avera',
#  'taolanaro',
#  'upernavik',
#  'omsukchan',
#  'balsas',
#  'cayenne',
#  'langham',
#  'guerrero negro',
#  'elat',
#  'quatre cocos',
#  'castro',
#  'geraldton',
#  'varzea da palma',
#  'barentsburg',
#  'obregon',
#  'eureka',
#  'kralendijk',
#  'olafsvik',
#  'arumbavur',
#  'kerman',
#  'cacoal',
#  'lorengau',
#  'khatanga',
#  'jamestown',
#  'lata',
#  'namibe',
#  'cidreira',
#  'puerto narino',
#  'beringovskiy',
#  'nikolskoye',
#  'albany',
#  'san rafael del sur',
#  'luderitz',
#  'kaitangata',
#  'khani',
#  'puerto carreno',
#  'hami',
#  'chokurdakh',
#  'belushya guba',
#  'kruisfontein',
#  'durazno',
#  'magadan',
#  'bullhead city',
#  'kodiak',
#  'saleaula',
#  'hobyo',
#  'puerto madryn',
#  'chuy',
#  'vao',
#  'iqaluit',
#  'thinadhoo',
#  'kavaratti',
#  'ormara',
#  'tiksi',
#  'ranong',
#  'vaini',
#  'port alfred',
#  'bur gabo',
#  'leningradskiy',
#  'amderma',
#  'progreso',
#  'murgab',
#  'kenora',
#  'oshakati',
#  'bury saint edmunds',
#  'necochea',
#  'wau',
#  'illoqqortoormiut',
#  'canavieiras',
#  'mbini',
#  'honiara',
#  'busselton',
#  'ambilobe',
#  'chimbote',
#  'hasaki',
#  'norman wells',
#  'komsomolskiy',
#  'eyl',
#  'talnakh',
#  'bengkulu',
#  'ponta do sol',
#  'hofn',
#  'ontario',
#  'nantucket',
#  'loreto',
#  'cabo san lucas',
#  'plymouth',
#  'pevek',
#  'mackenzie',
#  'jiwani',
#  'trzebnica',
#  'plettenberg bay',
#  'husavik',
#  'poum',
#  'tecoanapa',
#  'cefalu',
#  'salalah',
#  'beloha',
#  'mangrol',
#  'saint george',
#  'nyurba',
#  'yenagoa',
#  'kindu',
#  'victoria',
#  'woodward',
#  'turbat',
#  'forestville',
#  'ewa beach',
#  'teya',
#  'cascais',
#  'palabuhanratu',
#  'moscow',
#  'nanortalik',
#  'severo-kurilsk',
#  'constitucion',
#  'kirakira',
#  'bambous virieux',
#  'roald',
#  'capao bonito',
#  'turan',
#  'sao filipe',
#  'manta',
#  'manjacaze',
#  'saint-francois',
#  'arman',
#  'porto novo',
#  'campo maior',
#  'alvaraes',
#  'tiznit',
#  'nortelandia',
#  'high river',
#  'lompoc',
#  'airai',
#  'marshall',
#  'campoverde',
#  'sola',
#  'ginda',
#  'almaznyy',
#  'mtsensk',
#  'pisco',
#  'serebryansk',
#  'samusu',
#  'katsuura',
#  'alofi',
#  'abu dhabi',
#  'mehamn',
#  'kahului',
#  'hay river',
#  'batemans bay',
#  'torbay',
#  'chicomuselo',
#  'birao',
#  'hithadhoo',
#  'safita',
#  'bilma',
#  'ngama',
#  'jinchang',
#  'toora-khem',
#  'aykhal',
#  'bulgan',
#  'san cristobal',
#  'dikson',
#  'lodja',
#  'sentyabrskiy',
#  'souillac',
#  'fort nelson',
#  'kenai',
#  'haikou',
#  'rawson',
#  'sterling',
#  'dongsheng',
#  'attawapiskat',
#  'los llanos de aridane',
#  'gijon',
#  'valdivia',
#  'dumbrava rosie',
#  'irbit',
#  'naze',
#  'najran',
#  'lazaro cardenas',
#  'cabilocaan',
#  'port lincoln',
#  'socorro',
#  'bereda',
#  'amot',
#  'strezhevoy',
#  'give',
#  'buta',
#  'samarai',
#  'lapeer',
#  'lac du bonnet',
#  'marsh harbour',
#  'nioki',
#  'hue',
#  'berlevag',
#  'bubaque',
#  'bethel',
#  'tuggurt',
#  'carnarvon',
#  'arcata',
#  'touros',
#  'isiro',
#  'obudovac',
#  'puri',
#  'nakatunguru',
#  'sarhari',
#  'hualmay',
#  'la ronge',
#  'ketchikan',
#  'sataua',
#  'nishihara',
#  'labuan',
#  'batagay',
#  'burica',
#  'wattegama',
#  'opuwo',
#  'kyra',
#  'altay',
#  'mitsamiouli',
#  'itoman',
#  'bojaya',
#  'qaanaaq',
#  'fairbanks',
#  'punta alta',
#  'zyryanka',
#  'bilibino',
#  'tautira',
#  'graciano sanchez',
#  'funadhoo',
#  'vila velha',
#  'agirish',
#  'santa cruz',
#  'senador canedo',
#  'vila franca do campo',
#  'krishnagiri',
#  'saldanha',
#  'carmo do paranaiba',
#  'great falls',
#  'kununurra',
#  'kieta',
#  'lavrentiya',
#  'cap-aux-meules',
#  'rio tuba',
#  'penzance',
#  'baijiantan',
#  'ulaangom',
#  'upata',
#  'flinders',
#  'asau',
#  'giddalur',
#  'utete',
#  'hamilton',
#  'ancud',
#  'tasiilaq',
#  'lakes entrance',
#  'vardo',
#  'gazojak',
#  'tsihombe',
#  'nkhotakota',
#  'tanhacu',
#  'tanah merah',
#  'marathon',
#  'port-gentil',
#  'gizo',
#  'yulara',
#  'mitzic',
#  'abhar',
#  'huanren',
#  'teneguiban',
#  'oussouye',
#  'sao francisco',
#  'tevaitoa',
#  'brae',
#  'mbacke',
#  'labrea',
#  'viytivka',
#  'muroto',
#  'lethem',
#  'pochutla',
#  'kuala terengganu',
#  'kedrovyy',
#  'pangody',
#  'mitrofanovka',
#  'mys shmidta',
#  'schwabmunchen',
#  'coetupo',
#  'san isidro',
#  'carinhanha',
#  'adre',
#  'richmond',
#  'ovre ardal',
#  'ilulissat',
#  'anloga',
#  'waingapu',
#  'saint stephen',
#  'udachnyy',
#  'tanete',
#  'ibra',
#  'grand river south east',
#  'lasa',
#  'nurota',
#  'longlac',
#  'daoukro',
#  'halalo',
#  'padang',
#  'louisbourg',
#  'along',
#  'charleston',
#  'saint-joseph',
#  'yarovoye',
#  'miyako',
#  'nokaneng',
#  'aginskoye',
#  'constantine',
#  'kolokani',
#  'erzin',
#  'shar',
#  'senneterre',
#  'qena',
#  'dunedin',
#  'maghama',
#  'longyearbyen',
#  'baruun-urt',
#  'tres arroyos',
#  'itarema',
#  'ciras',
#  'cabinda',
#  'ban dung',
#  'shelburne',
#  'tamandare',
#  'tyret pervaya',
#  'marcona',
#  'kingman',
#  'reforma',
#  'ushtobe',
#  'abha',
#  'carauari',
#  'the valley',
#  'coahuayana',
#  'tam ky',
#  'carutapera',
#  'tual',
#  'jiazi',
#  'kuju',
#  'isla mujeres',
#  'taga',
#  'ambodifototra',
#  'luganville',
#  'shache',
#  'julio de castilhos',
#  'kamariotissa',
#  'guarapari',
#  'koslan',
#  'ossora',
#  'imeni poliny osipenko',
#  'grande prairie',
#  'abbotsford',
#  'usinsk',
#  'taltal',
#  'gunjur',
#  'amahai',
#  'tubruq',
#  'jiexiu',
#  'porto belo',
#  'loiza',
#  'guayaramerin',
#  'vestmannaeyjar',
#  'moerai',
#  'saint-pierre',
#  'zhob',
#  'show low',
#  'oksfjord',
#  'kjollefjord',
#  'sonta',
#  'chumikan',
#  'beyneu',
#  'gorno-chuyskiy',
#  'ahipara',
#  'samalaeulu',
#  'ranikhet',
#  'le vauclin',
#  'luanda',
#  'faanui',
#  'sao joao da barra',
#  'mlonggo',
#  'havre-saint-pierre',
#  'weinan',
#  'talara',
#  'mumford',
#  'apastepeque',
#  'tuatapere',
#  'aklavik',
#  'grand centre',
#  'hammerfest',
#  'havoysund',
#  'jurmala',
#  'hambantota',
#  'whitecourt',
#  'marsabit',
#  'bud',
#  'mayo',
#  'waipawa',
#  'yuzhno-yeniseyskiy',
#  'matara',
#  'oga',
#  'dhidhdhoo',
#  'tezu',
#  'pangnirtung',
#  'kupang',
#  'kloulklubed',
#  'narbonne',
#  'maarianhamina',
#  'port hardy',
#  'namwala',
#  'klaksvik',
#  'juifang',
#  'pampa',
#  'vanavara',
#  'barwaha',
#  'palmer',
#  'qaqortoq',
#  'garowe',
#  'maceio',
#  'narsaq',
#  'utiroa',
#  'lulea',
#  'mecca',
#  'iwaki',
#  'el alto',
#  'kulhudhuffushi',
#  'davidson',
#  'broken hill',
#  'adrar',
#  'pringsewu',
#  'tukrah',
#  'atasu',
#  'rockland',
#  'mangai',
#  'yakima',
#  'shasta lake',
#  'puerto baquerizo moreno',
#  'urdzhar',
#  'pacific grove',
#  'rio grande',
#  'sandakan',
#  'lima',
#  'half moon bay',
#  'khandyga',
#  'tanout',
#  'conceicao do araguaia',
#  'harindanga',
#  'tabou',
#  'tura',
#  'price',
#  'saquarema',
#  'sakaiminato',
#  'ostroh',
#  'ponto novo',
#  'morehead',
#  'bosaso',
#  'salinopolis',
#  'tucumcari',
#  'ust-maya',
#  'loandjili',
#  'bathsheba',
#  'korla',
#  'chapada dos guimaraes',
#  'bonavista',
#  'bac lieu',
#  'high rock',
#  'collie',
#  'kapit',
#  'provideniya',
#  'manoel urbano',
#  'skalistyy',
#  'ilesha',
#  'jardim',
#  'bukoba',
#  'haebaru',
#  'acapulco',
#  'novoagansk',
#  'muravlenko',
#  'kesova gora',
#  'camara de lobos',
#  'faya',
#  'one hundred mile house',
#  'gigmoto',
#  'portland',
#  'kanbe',
#  'hirara',
#  'makakilo city',
#  'port hedland',
#  'namatanai',
#  'cochrane',
#  'bhongir',
#  'nome',
#  'kuzhithurai',
#  'baherden',
#  'soe',
#  'solnechnyy',
#  'vaitupu',
#  'catuday',
#  'rio claro',
#  'mocambique',
#  'saint-denis',
#  'shilovo',
#  'vicosa do ceara',
#  'clyde river',
#  'barawe',
#  'pau',
#  'milkovo',
#  'buraydah',
#  'ponta delgada',
#  'concepcion',
#  'lisakovsk',
#  'belmonte',
#  'narimanov',
#  'baghdad',
#  'bathurst',
#  'oranjestad',
#  'nata',
#  'maragogi',
#  'vanderhoof',
#  'kedgwick',
#  'mancio lima',
#  'rudbar',
#  'sao raimundo nonato',
#  'haines junction',
#  'saint anthony',
#  'codrington',
#  'pogar',
#  'gbadolite',
#  'mandalgovi',
#  'wilmington',
#  'sosva',
#  'wollongong',
#  'bosobolo',
#  'kemlya',
#  'nelson bay',
#  'doncaster',
#  'palana',
#  'sorland',
#  'yablonovo',
#  'siva',
#  'grindavik',
#  'dongying',
#  'ikole',
#  'samoded',
#  'umzimvubu']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=6bbc6f9aa8c2d78e5b37d1a8c9cd4e68&units=imperial&q='

# %%
# This creates a loop that pulls out the weather data for each city name in the list.
weather=np.array([])
data = ()

# set up lists to hold response info
lat = []
temp = []
cloudiness = []
country = []
humidity =[]
lat =[]
lng = []
temp = []
wind_speed = []
city_name = []
index_counter = 0
set_counter = 1


for index, city in enumerate(cities, start =1):
        
    try:
        response = requests.get(query_url + city).json()
        
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        
        if index_counter >49:
            index_counter = 0
            set_counter = set_counter +1
            
        else:
            index_counter = index_counter + 1
            
        print(f"Processing city {index_counter} of Set {set_counter} : {city}")   
    
    except (KeyError, IndexError):
        print ("Error - skip.")

print("Done")
# Out:
# Processing city 1 of Set 1 : jorochito
# Processing city 2 of Set 1 : ushuaia
# Processing city 3 of Set 1 : yellowknife
# Processing city 4 of Set 1 : cherskiy
# Processing city 5 of Set 1 : rock sound
# Processing city 6 of Set 1 : sfantu gheorghe
# Processing city 7 of Set 1 : santa isabel do rio negro
# Processing city 8 of Set 1 : camacha
# Processing city 9 of Set 1 : chapais
# Processing city 10 of Set 1 : caravelas
# Processing city 11 of Set 1 : yeniseysk
# Processing city 12 of Set 1 : mataura
# Processing city 13 of Set 1 : ogulin
# Processing city 14 of Set 1 : atuona
# Error - skip.
# Processing city 15 of Set 1 : jacareacanga
# Processing city 16 of Set 1 : ballina
# Error - skip.
# Processing city 17 of Set 1 : labuhan
# Processing city 18 of Set 1 : punta arenas
# Processing city 19 of Set 1 : ust-barguzin
# Processing city 20 of Set 1 : rikitea
# Processing city 21 of Set 1 : hermanus
# Processing city 22 of Set 1 : maamba
# Processing city 23 of Set 1 : sitka
# Processing city 24 of Set 1 : rjukan
# Processing city 25 of Set 1 : arys
# Processing city 26 of Set 1 : barrow
# Processing city 27 of Set 1 : noyabrsk
# Processing city 28 of Set 1 : butaritari
# Processing city 29 of Set 1 : verkhnyaya inta
# Processing city 30 of Set 1 : mar del plata
# Processing city 31 of Set 1 : puerto ayora
# Processing city 32 of Set 1 : hobart
# Processing city 33 of Set 1 : bluff
# Processing city 34 of Set 1 : saint-philippe
# Processing city 35 of Set 1 : ahuimanu
# Processing city 36 of Set 1 : christchurch
# Processing city 37 of Set 1 : saskylakh
# Processing city 38 of Set 1 : todos santos
# Processing city 39 of Set 1 : raga
# Processing city 40 of Set 1 : thompson
# Processing city 41 of Set 1 : port elizabeth
# Processing city 42 of Set 1 : avarua
# Processing city 43 of Set 1 : lalmohan
# Processing city 44 of Set 1 : cape town
# Processing city 45 of Set 1 : san jeronimo
# Error - skip.
# Processing city 39 of Set 4 : severo-kurilsk
# Processing city 40 of Set 4 : constitucion
# Processing city 41 of Set 4 : kirakira
# Processing city 42 of Set 4 : bambous virieux
# Processing city 43 of Set 4 : roald
# Processing city 44 of Set 4 : capao bonito
# Processing city 45 of Set 4 : turan
# Processing city 46 of Set 4 : sao filipe
# Processing city 47 of Set 4 : manta
# Processing city 48 of Set 4 : manjacaze
# Processing city 49 of Set 4 : saint-francois
# Processing city 50 of Set 4 : arman
# Processing city 0 of Set 5 : porto novo
# Processing city 1 of Set 5 : campo maior
# Processing city 2 of Set 5 : alvaraes
# Processing city 3 of Set 5 : tiznit
# Processing city 4 of Set 5 : nortelandia
# Processing city 5 of Set 5 : high river
# Processing city 6 of Set 5 : lompoc
# Processing city 7 of Set 5 : airai
# Processing city 8 of Set 5 : marshall
# Processing city 9 of Set 5 : campoverde
# Processing city 10 of Set 5 : sola
# Processing city 11 of Set 5 : ginda
# Processing city 12 of Set 5 : almaznyy
# Processing city 13 of Set 5 : mtsensk
# Processing city 14 of Set 5 : pisco
# Processing city 15 of Set 5 : serebryansk
# Error - skip.
# Processing city 16 of Set 5 : katsuura
# Processing city 17 of Set 5 : alofi
# Processing city 18 of Set 5 : abu dhabi
# Processing city 19 of Set 5 : mehamn
# Processing city 20 of Set 5 : kahului
# Processing city 21 of Set 5 : hay river
# Processing city 22 of Set 5 : batemans bay
# Processing city 23 of Set 5 : torbay
# Processing city 24 of Set 5 : chicomuselo
# Processing city 25 of Set 5 : birao
# Processing city 26 of Set 5 : hithadhoo
# Processing city 27 of Set 5 : safita
# Processing city 28 of Set 5 : bilma
# Processing city 29 of Set 5 : ngama
# Processing city 30 of Set 5 : jinchang
# Processing city 31 of Set 5 : toora-khem
# Processing city 32 of Set 5 : aykhal
# Processing city 33 of Set 5 : bulgan
# Processing city 34 of Set 5 : san cristobal
# Processing city 35 of Set 5 : dikson
# Processing city 36 of Set 5 : lodja
# Error - skip.
# Processing city 37 of Set 5 : souillac
# Processing city 38 of Set 5 : fort nelson
# Processing city 39 of Set 5 : kenai
# Processing city 40 of Set 5 : haikou
# Processing city 41 of Set 5 : rawson
# Processing city 42 of Set 5 : sterling
# Processing city 43 of Set 5 : dongsheng
# Error - skip.
# Processing city 44 of Set 5 : los llanos de aridane
# Processing city 45 of Set 5 : gijon
# Processing city 46 of Set 5 : valdivia
# Processing city 47 of Set 5 : dumbrava rosie
# Processing city 48 of Set 5 : irbit
# Processing city 49 of Set 5 : naze
# Processing city 50 of Set 5 : najran
# Processing city 0 of Set 6 : lazaro cardenas
# Processing city 1 of Set 6 : cabilocaan
# Processing city 2 of Set 6 : port lincoln
# Processing city 3 of Set 6 : socorro
# Processing city 4 of Set 6 : bereda
# Processing city 5 of Set 6 : amot
# Processing city 6 of Set 6 : strezhevoy
# Processing city 7 of Set 6 : give
# Processing city 8 of Set 6 : buta
# Processing city 9 of Set 6 : samarai
# Processing city 10 of Set 6 : lapeer
# Processing city 11 of Set 6 : lac du bonnet
# Processing city 43 of Set 11 : clyde river
# Error - skip.
# Processing city 44 of Set 11 : pau
# Processing city 45 of Set 11 : milkovo
# Processing city 46 of Set 11 : buraydah
# Processing city 47 of Set 11 : ponta delgada
# Processing city 48 of Set 11 : concepcion
# Processing city 49 of Set 11 : lisakovsk
# Processing city 50 of Set 11 : belmonte
# Processing city 0 of Set 12 : narimanov
# Processing city 1 of Set 12 : baghdad
# Processing city 2 of Set 12 : bathurst
# Processing city 3 of Set 12 : oranjestad
# Processing city 4 of Set 12 : nata
# Processing city 5 of Set 12 : maragogi
# Processing city 6 of Set 12 : vanderhoof
# Processing city 7 of Set 12 : kedgwick
# Processing city 8 of Set 12 : mancio lima
# Processing city 9 of Set 12 : rudbar
# Processing city 10 of Set 12 : sao raimundo nonato
# Processing city 11 of Set 12 : haines junction
# Processing city 12 of Set 12 : saint anthony
# Processing city 13 of Set 12 : codrington
# Processing city 14 of Set 12 : pogar
# Processing city 15 of Set 12 : gbadolite
# Processing city 16 of Set 12 : mandalgovi
# Processing city 17 of Set 12 : wilmington
# Processing city 18 of Set 12 : sosva
# Processing city 19 of Set 12 : wollongong
# Processing city 20 of Set 12 : bosobolo
# Processing city 21 of Set 12 : kemlya
# Processing city 22 of Set 12 : nelson bay
# Processing city 23 of Set 12 : doncaster
# Processing city 24 of Set 12 : palana
# Processing city 25 of Set 12 : sorland
# Processing city 26 of Set 12 : yablonovo
# Processing city 27 of Set 12 : siva
# Processing city 28 of Set 12 : grindavik
# Processing city 29 of Set 12 : dongying
# Error - skip.
# Processing city 30 of Set 12 : samoded
# Error - skip.
# Done

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data2_df = pd.DataFrame({
    "city": city_name,
    "country": country,
    "lat": lat,
    "temp": temp,
    "humidity": humidity,
    "cloudiness": cloudiness,
    "wind speed": wind_speed

})
   
weather_data2.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-0bbe4c4ad7c2> in <module>
#      10 })
#      11
# ---> 12 weather_data2.count()
#
# NameError: name 'weather_data2' is not defined

# %%
weather_data2_df
# Out:
#             city country    lat   temp  humidity  cloudiness  wind speed
# 0      Jorochito      BO -18.05  82.40        69           5        3.36
# 1        Ushuaia      AR -54.80  46.40        70          90        5.82
# 2    Yellowknife      CA  62.46  33.57        64          75       24.16
# 3       Cherskiy      RU  68.75  24.67        86          53        9.86
# 4     Rock Sound      BS  24.90  83.26        73         100        3.83
# ..           ...     ...    ...    ...       ...         ...         ...
# 586    Yablonovo      RU  50.85  53.60       100          90        4.47
# 587        Sīwah      EG  29.20  69.85        54           0        4.74
# 588    Grindavik      IS  63.84  41.00       100          75        8.05
# 589     Dongying      CN  37.46  65.01        27           7        6.60
# 590      Samoded      RU  63.61  47.61        95         100        6.51
#
# [591 rows x 7 columns]

# %%
weather_data2_df.to_csv("output_data/cities.csv", index = False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# print(weather_data2_df[(city_name)].where(weather_data2_df[(humidity)] > 100))

h_humid_df = weather_data2_df[weather_data2_df['humidity'] > (100)]
h_humid_df
# Out:
# Empty DataFrame
# Columns: [city, country, lat, temp, humidity, cloudiness, wind speed]
# Index: []

# %%
# There are no cities with humidity greater than 100**


#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.title("Latitude vs. Temperature Plot")
plt.xlabel("Latitude (deg)")
plt.ylabel("Temperature (F)")

plt.scatter(lat,temp)
plt.show(lat,temp)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.title("Latitude vs. Humidity Plot")
plt.xlabel("Latitude (deg)")
plt.ylabel("Humidity (%)")

plt.scatter(lat,humidity)
plt.show(lat,humidity)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.title("Latitude vs. Cloudiness Plot")
plt.xlabel("Latitude (deg)")
plt.ylabel("Cloudiness (%)")

plt.scatter(lat,cloudiness)
plt.show(lat,cloudiness)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.title("Latitude vs. Wind Speed Plot")
plt.xlabel("Latitude (deg)")
plt.ylabel("Wind Speed (mph)")

plt.scatter(lat,wind_speed)
plt.show(lat,wind_speed)

# %% [markdown]
# ## Linear Regression

# %%
north = weather_data2_df['lat']>0
print(north.head())

south = weather_data2_df['lat']<0
print(south.head())
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: lat, dtype: bool
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: lat, dtype: bool

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
weather_datan_df = weather_data2_df[north]
print(weather_datan_df.tail())

weather_datas_df = weather_data2_df[south]
print(weather_datas_df.tail())
# Out:
#           city country    lat   temp  humidity  cloudiness  wind speed
# 586  Yablonovo      RU  50.85  53.60       100          90        4.47
# 587      Sīwah      EG  29.20  69.85        54           0        4.74
# 588  Grindavik      IS  63.84  41.00       100          75        8.05
# 589   Dongying      CN  37.46  65.01        27           7        6.60
# 590    Samoded      RU  63.61  47.61        95         100        6.51
#                     city country    lat   temp  humidity  cloudiness  \
# 568          Mâncio Lima      BR  -7.61  80.98        53          15
# 570  São Raimundo Nonato      BR  -9.02  81.10        44           3
# 573           Codrington      AU -38.27  57.00        79         100
# 579           Wollongong      AU -34.43  79.36        39           0
# 582           Nelson Bay      AU -32.72  75.65        50          20
#
#      wind speed
# 568        2.62
# 570        0.92
# 573       12.46
# 579        4.00
# 582        8.05

# %%
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")



x = weather_datan_df["lat"]
y = weather_datan_df["temp"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Temp Max (F)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is -0.86
# The r-squared is: 0.740501239687636
# The regression equation is: y = -0.83x + 89.32

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")



x = weather_datas_df["lat"]
y = weather_datas_df["temp"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Temp Max (F)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.69
# The r-squared is: 0.4720051488473213
# The regression equation is: y = 0.53x + 81.07

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")



x = weather_datan_df["lat"]
y = weather_datan_df["humidity"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.07
# The r-squared is: 0.0046402645921030635
# The regression equation is: y = 0.07x + 72.46

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")



x = weather_datas_df["lat"]
y = weather_datas_df["humidity"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.25
# The r-squared is: 0.06218937746617736
# The regression equation is: y = 0.33x + 78.53

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude (deg)")
plt.ylabel("Cloudiness (%)")



x = weather_datan_df["lat"]
y = weather_datan_df["cloudiness"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.15
# The r-squared is: 0.023747261572341135
# The regression equation is: y = 0.31x + 40.4

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude (deg)")
plt.ylabel("Cloudiness (%)")



x = weather_datas_df["lat"]
y = weather_datas_df["cloudiness"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.18
# The r-squared is: 0.03202597029937728
# The regression equation is: y = 0.51x + 50.6

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude (deg)")
plt.ylabel("Wind Speed (mph)")



x = weather_datan_df["lat"]
y = weather_datan_df["wind speed"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.06
# The r-squared is: 0.003478543935023158
# The regression equation is: y = 0.02x + 7.31

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude (deg)")
plt.ylabel("Wind Speed (mph)")



x = weather_datas_df["lat"]
y = weather_datas_df["wind speed"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is -0.11
# The r-squared is: 0.012324074851877725
# The regression equation is: y = -0.04x + 6.97
