# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Installing citipy module
#!pip install citipy
from citipy import citipy

# Dependencies
import pandas as pd
import numpy as np
import requests
import json

from scipy import stats
import matplotlib.pyplot as plt

# Google API Key
from api_keys import g_key
from api_keys import weather_api_key
from itertools import product
from itertools import permutations
# print (weather_api_key)

# %% [markdown]
# ## Generate Cities List

# %%
#** Real code for project
#**********Need to fix the limit, gives more than 500 values***************

x_axis=np.random.randint(-90, 90, size=5000)
y_axis=np.random.randint(-180, 180, size=5000)

cities=[]
names=[]
coordinates=[]
for i in range(5000):
    coordinates.append((x_axis[i], y_axis[i]))
    coordinates
    
for coordinate_pair in coordinates:
    lat, lon = coordinate_pair
    cities.append(citipy.nearest_city(lat, lon))
    
for city in cities:
    country_code = city.country_code
    name = city.city_name
    names.append(name)
   
    names_series=pd.Series(names)

# %%
#** Real code for project

names
# Out:
# ['east london',
#  'cape town',
#  'morondava',
#  'arraial do cabo',
#  'klyuchi',
#  'huejuquilla el alto',
#  'busselton',
#  'calamar',
#  'meulaboh',
#  'arteaga',
#  'feijo',
#  'hilo',
#  'vaitupu',
#  'hithadhoo',
#  'east london',
#  'kamenka',
#  'upernavik',
#  'husavik',
#  'rikitea',
#  'falam',
#  'alofi',
#  'zhigansk',
#  'victoria',
#  'bluff',
#  'busselton',
#  'port-gentil',
#  'ushuaia',
#  'dikson',
#  'carnarvon',
#  'vaini',
#  'touros',
#  'busselton',
#  'palabuhanratu',
#  'barentsburg',
#  'meulaboh',
#  'olafsvik',
#  'ushuaia',
#  'busselton',
#  'port alfred',
#  'mokhsogollokh',
#  'honiara',
#  'khatanga',
#  'hobart',
#  'mataura',
#  'dingle',
#  'vaini',
#  'joshimath',
#  'puerto madero',
#  'ushuaia',
#  'punta arenas',
#  'codrington',
#  'jamestown',
#  'meyungs',
#  'hilo',
#  'ushuaia',
#  'rikitea',
#  'kaeo',
#  'clyde river',
#  'ribeira brava',
#  'saryshagan',
#  'ushuaia',
#  'ushuaia',
#  'albany',
#  'tuburan',
#  'umzimvubu',
# ...

# %%
#** Real code for project

names_series
# Out:
# 0           east london
# 1             cape town
# 2             morondava
# 3       arraial do cabo
# 4               klyuchi
#              ...
# 4995            rikitea
# 4996       sentyabrskiy
# 4997     treinta y tres
# 4998      mar del plata
# 4999             kodiak
# Length: 5000, dtype: object

# %%
#** Real code for project
len(names_series)
# Out:
# 5000

# %%
# Test code to figure it out
villages = ["Palatine", "Paris", "London", "Oslo", "Beijing"]
len(villages)
# Out:
# 5

# %%
 # Test code to figure it out
villages_series=pd.Series(villages)
villages_series
# Out:
# 0    Palatine
# 1       Paris
# 2      London
# 3        Oslo
# 4     Beijing
# dtype: object

# %%
# Test code to figure it out

weather=np.array([])
data = ()

# set up lists to hold response info
lat = []
temp = []
cloudiness = []
country = []
humidity =[]
lat =[]
lng = []
temp = []
wind_speed = []

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"


for x in range(len(villages)):
   
    print(f"Processing city: {x} of {len(villages)}: {villages[x]}")
    response=requests.get(url + "appid=" + weather_api_key + "&q=" + villages[x] + "&units=" + units).json()  
        
    try:    
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])

        weather_list=np.append(weather, data)
        weather_list
        
        if len(wind_speed)==30:
            break
    
    except KeyError:
        print ("error")
        pass
# Out:
# Processing city: 0 of 5: Palatine
# Processing city: 1 of 5: Paris
# Processing city: 2 of 5: London
# Processing city: 3 of 5: Oslo
# Processing city: 4 of 5: Beijing

# %%
# Test code to figure it out



weather_dict = {
    "city": villages,
    "lat": lat,
    "temp": temp,
    "humidity": humidity,
    "cloudiness": cloudiness,
    "wind speed": wind_speed

}

# weather_data = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in weather_dict.items() ]))
# weather_data = pd.DataFrame.from_dict(weather_dict, orient='index').transpose()

# weather_data = pd.DataFrame.from_dict(weather_dict, orient='index')
# weather_data.transpose()


weather_data = pd.DataFrame(weather_dict)




weather_data.head()
# Out:
#        city    lat   temp  humidity  cloudiness  wind speed
# 0  Palatine  42.11  61.09        77           1        4.70
# 1     Paris  48.85  45.52        93           3        6.93
# 2    London  51.51  46.35        76          93        3.36
# 3      Oslo  59.91  42.69        85           8        1.99
# 4   Beijing  39.91  56.19        35           0        3.87

# %%
#** Real code for project
names
# Out:
# ['east london',
#  'cape town',
#  'morondava',
#  'arraial do cabo',
#  'klyuchi',
#  'huejuquilla el alto',
#  'busselton',
#  'calamar',
#  'meulaboh',
#  'arteaga',
#  'feijo',
#  'hilo',
#  'vaitupu',
#  'hithadhoo',
#  'east london',
#  'kamenka',
#  'upernavik',
#  'husavik',
#  'rikitea',
#  'falam',
#  'alofi',
#  'zhigansk',
#  'victoria',
#  'bluff',
#  'busselton',
#  'port-gentil',
#  'ushuaia',
#  'dikson',
#  'carnarvon',
#  'vaini',
#  'touros',
#  'busselton',
#  'palabuhanratu',
#  'barentsburg',
#  'meulaboh',
#  'olafsvik',
#  'ushuaia',
#  'busselton',
#  'port alfred',
#  'mokhsogollokh',
#  'honiara',
#  'khatanga',
#  'hobart',
#  'mataura',
#  'dingle',
#  'vaini',
#  'joshimath',
#  'puerto madero',
#  'ushuaia',
#  'punta arenas',
#  'codrington',
#  'jamestown',
#  'meyungs',
#  'hilo',
#  'ushuaia',
#  'rikitea',
#  'kaeo',
#  'clyde river',
#  'ribeira brava',
#  'saryshagan',
#  'ushuaia',
#  'ushuaia',
#  'albany',
#  'tuburan',
#  'umzimvubu',
# ...

# %%
#** Real code for project
# This creates a loop that pulls out the weather data for each city name in the list.
weather1=np.array([])
data = ()


# set up lists to hold reponse info
lat = []
temp = []
cloudiness = []
country = []
humidity =[]
lat =[]
lng = []
temp = []
wind_speed = []

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"


for x in range(len(names)):
    print(f"Processing city: {x} of {len(names)}: {names[x]}")
    response=requests.get(url + "appid=" + weather_api_key + "&q=" + names[x] + "&units=" + units).json()
    
    lat.append(response['coord']['lat'])
    temp.append(response['main']['temp'])
    humidity.append(response['main']['humidity'])
    cloudiness.append(response['clouds']['all'])
    wind_speed.append(response['wind']['speed'])
        
    weather_list2=np.append(weather1, data)
    weather_list2
# Out:
# Processing city: 0 of 1101: plettenberg bay
# Processing city: 1 of 1101: yining
# Processing city: 2 of 1101: middlebury
# Processing city: 3 of 1101: kerman
# Processing city: 4 of 1101: jamestown
# Processing city: 5 of 1101: port alfred
# Processing city: 6 of 1101: mar del plata
# Processing city: 7 of 1101: ancud
# Processing city: 8 of 1101: ushuaia
# Processing city: 9 of 1101: kovdor
# Processing city: 10 of 1101: vilyuysk
# Processing city: 11 of 1101: esperance
# Processing city: 12 of 1101: ribeira grande
# Processing city: 13 of 1101: kahului
# Processing city: 14 of 1101: barawe
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-17f80beafa9b> in <module>
#      24     response=requests.get(url + "appid=" + weather_api_key + "&q=" + names[x] + "&units=" + units).json()
#      25
# ---> 26     lat.append(response['coord']['lat'])
# ...

# %%
#** Real code for project


weather_dict2 = {
    "city": villages,
    "lat": lat,
    "temp": temp,
    "humidity": humidity,
    "cloudiness": cloudiness,
    "wind speed": wind_speed

}
weather_data2 = pd.DataFrame(weather_dict2)
weather_data2.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-0a73b334f2c1> in <module>
#      11
#      12 }
# ---> 13 weather_data2 = pd.DataFrame(weather_dict2)
#      14 weather_data2.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
# ...

# %%
#** Real code for project
names_series
# Out:
# 0       plettenberg bay
# 1                yining
# 2            middlebury
# 3                kerman
# 4             jamestown
#              ...
# 1096            rikitea
# 1097            sindand
# 1098           flinders
# 1099           khatanga
# 1100           chipinge
# Length: 1101, dtype: object

# %%
#** Real code for project
names
# Out:
# ['pacifica',
#  'albany',
#  'hithadhoo',
#  'kapaa',
#  'chokurdakh',
#  'cabo san lucas',
#  'vaitupu',
#  'avarua',
#  'peleduy',
#  'fare',
#  'khatanga',
#  'loutros',
#  'rikitea',
#  'chipinge',
#  'birin',
#  'chagda',
#  'dvinskoy',
#  'vaini',
#  'hermanus',
#  'port blair',
#  'poum',
#  'pevek',
#  'khatanga',
#  'axim',
#  'severo-kurilsk',
#  'salalah',
#  'kodiak',
#  'pedra azul',
#  'khatanga',
#  'lisiy nos',
#  'abu kamal',
#  'new norfolk',
#  'verkhnyaya inta',
#  'airai',
#  'jamestown',
#  'ushuaia',
#  'hasaki',
#  'high level',
#  'bluff',
#  'mwinilunga',
#  'kapaa',
#  'saleaula',
#  'cape town',
#  'port alfred',
#  'qurayyat',
#  'ruatoria',
#  'gorontalo',
#  'kishi',
#  'nikolskoye',
#  'vaini',
#  'rikitea',
#  'mar del plata',
#  'kirakira',
#  'lavrentiya',
#  'rikitea',
#  'barentsburg',
#  'rikitea',
#  'hilo',
#  'hilo',
#  'qaanaaq',
#  'nikolskoye',
#  'castro',
#  'jamestown',
#  'atuona',
#  'lebu',
#  'stavropol',
#  'mataura',
# ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#** Real code for project

# This creates a loop that pulls out the weather data for each city name in the list.
weather=np.array([])

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"


for x in range(len(villages)):
    print(f"Processing city: {x} of {len(villages)}: {villages[x]}")
    response=requests.get(url + "appid=" + weather_api_key + "&q=" + villages[x] + "&units=" + units).json()
    weather=np.append(weather, data)
# Out:
# Processing city: 0 of 5: Palatine
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-893ee266d5fe> in <module>
#       9     print(f"Processing city: {x} of {len(villages)}: {villages[x]}")
#      10     response=requests.get(url + "appid=" + weather_api_key + "&q=" + villages[x] + "&units=" + units).json()
# ---> 11     weather=np.append(weather, data)
#      12
#
# NameError: name 'data' is not defined

# %%
#** Real code for project

weather
# Out:
# array([], dtype=float64)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#** Real code for project

# Now need to extract columns from data source to build the table.

table_detail = []
lat_data = 0
temp_data = 0
for place in weather:
    lat_data = place.get("coord").get("lat")
    temp_data = place.get("main").get("temp")
    humidity_data = place.get("main").get("humidity")
    cloud_data = place.get("clouds").get("all")
    wind_data = place.get("wind").get("speed")
    
    extract = {'name': place.get('name'),"temp": temp_data, "lat": lat_data, "humidity": humidity_data, "clouds": cloud_data, "speed": wind_data}
    table_detail.append(extract)
    
    city_weather_data_df = pd.DataFrame(table_detail)

# %%
#** Real code for project

city_weather_data_df

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
