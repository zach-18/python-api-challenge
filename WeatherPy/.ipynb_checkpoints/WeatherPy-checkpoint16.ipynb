# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Installing citipy module
#!pip install citipy
from citipy import citipy

# Dependencies
import pandas as pd
import numpy as np
import requests
import json

from scipy import stats
import matplotlib.pyplot as plt

# Google API Key
from api_keys import g_key
from api_keys import weather_api_key
from itertools import product
from itertools import permutations
# print (weather_api_key)

# %% [markdown]
# ## Generate Cities List

# %%
#**********Need to fix the limit, gives more than 500 values***************

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1600)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1600)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %%
cities
# Out:
# ['port hardy',
#  'rikitea',
#  'fonte boa',
#  'batagay-alyta',
#  'mataura',
#  'ancud',
#  'albany',
#  'rawson',
#  'henties bay',
#  'dickinson',
#  'butaritari',
#  'saint-philippe',
#  'taolanaro',
#  'bredasdorp',
#  'upernavik',
#  'amderma',
#  'saint-pierre',
#  'punta arenas',
#  'ribeira grande',
#  'georgetown',
#  'hobart',
#  'ushuaia',
#  'mahebourg',
#  'puerto ayora',
#  'rio gallegos',
#  'kibaya',
#  'cotonou',
#  'norman wells',
#  'gweta',
#  'bontang',
#  'nizhneyansk',
#  'longyearbyen',
#  'avera',
#  'lusaka',
#  'dikson',
#  'qaanaaq',
#  'mpika',
#  'barentsburg',
#  'saskylakh',
#  'irati',
#  'ostrovnoy',
#  'vanimo',
#  'nome',
#  'samusu',
#  'niono',
#  'yellowknife',
#  'hermanus',
#  'nioro',
#  'bijar',
#  'ponta do sol',
#  'rock sound',
#  'mount gambier',
#  'formoso do araguaia',
#  'verkh-usugli',
#  'siguiri',
#  'port-gentil',
#  'acarau',
#  'tiksi',
#  'port alfred',
#  'kindu',
#  'claresholm',
#  'faanui',
#  'cape town',
#  'ilam',
#  'muriwai beach',
#  'arraial do cabo',
#  'portland',
#  'sibolga',
#  'bambanglipuro',
#  'gobabis',
#  'lebu',
#  'sao sebastiao',
#  'okhotsk',
#  'corowa',
#  'west bay',
#  'thompson',
#  'jamestown',
#  'hilo',
#  'tasiilaq',
#  'vaitupu',
#  'dobbs ferry',
#  'mirabad',
#  'port macquarie',
#  'san patricio',
#  'vaini',
#  'aloleng',
#  'antofagasta',
#  'tumannyy',
#  'attawapiskat',
#  'saquena',
#  'vilyuysk',
#  'codrington',
#  'nemuro',
#  'vila franca do campo',
#  'nandigama',
#  'busselton',
#  'bad neustadt',
#  'bubaque',
#  'mar del plata',
#  'nelson bay',
#  'avarua',
#  'russell',
#  'lannion',
#  'abu dhabi',
#  'kamaishi',
#  'ust-kalmanka',
#  'pitimbu',
#  'usogorsk',
#  'leningradskiy',
#  'kaitangata',
#  'kloulklubed',
#  'roma',
#  'goderich',
#  'tynda',
#  'santander',
#  'dalvik',
#  'columbus',
#  'coxim',
#  'bambous virieux',
#  'luderitz',
#  'kodiak',
#  'castro',
#  'san policarpo',
#  'cidreira',
#  'sharlyk',
#  'la asuncion',
#  'havre-saint-pierre',
#  'imbituba',
#  'barrow',
#  'atuona',
#  'sepolno krajenskie',
#  'labuhan',
#  'bethel',
#  'tuktoyaktuk',
#  'saint-georges',
#  'naze',
#  'sandane',
#  'takoradi',
#  'san cristobal',
#  'hobyo',
#  'flinders',
#  'rungata',
#  'carepa',
#  'vila velha',
#  'kapaa',
#  'punta alta',
#  'nagato',
#  'pangnirtung',
#  'sitka',
#  'new norfolk',
#  'esperance',
#  'namibe',
#  'grindavik',
#  'tocopilla',
#  'nikolskoye',
#  'hithadhoo',
#  'waipawa',
#  'mao',
#  'sept-iles',
#  'praia',
#  'ilulissat',
#  'chipinge',
#  'havelock',
#  'khatanga',
#  'abashiri',
#  'lagoa',
#  'richard toll',
#  'dubbo',
#  'sydney',
#  'grand river south east',
#  'sodertalje',
#  'raduzhnyy',
#  'port shepstone',
#  'puerto baquerizo moreno',
#  'deputatskiy',
#  'sawtell',
#  'pevek',
#  'maragogi',
#  'abu samrah',
#  'impfondo',
#  'illoqqortoormiut',
#  'rafai',
#  'moose factory',
#  'belushya guba',
#  'mecca',
#  'bluff',
#  'sisimiut',
#  'kruisfontein',
#  'cayenne',
#  'kumla',
#  'puri',
#  'east london',
#  'verkhoyansk',
#  'rohnert park',
#  'batemans bay',
#  'yar-sale',
#  'mapiri',
#  'manbij',
#  'provideniya',
#  'richards bay',
#  'moba',
#  'san vicente',
#  'geraldton',
#  'beaver dam',
#  'college',
#  'te anau',
#  'airai',
#  'idaho falls',
#  'carnarvon',
#  'mehamn',
#  'lavrentiya',
#  'san quintin',
#  'kabalo',
#  'plettenberg bay',
#  'husavik',
#  'narsaq',
#  'palabuhanratu',
#  'victoria',
#  'santa ines',
#  'erzin',
#  'santa rosalia',
#  'hovd',
#  'teguldet',
#  'lompoc',
#  'astana',
#  'kijini',
#  'klaksvik',
#  'isangel',
#  'haines junction',
#  'bolshoye ignatovo',
#  'kilindoni',
#  'rafaela',
#  'iqaluit',
#  'arvika',
#  'la ronge',
#  'hasaki',
#  'saint george',
#  'shimanovsk',
#  'fortuna',
#  'farkhor',
#  'matay',
#  'chuy',
#  'menongue',
#  'dolbeau',
#  'magui',
#  'brive-la-gaillarde',
#  'kifri',
#  'polikastron',
#  'janakpur',
#  'merauke',
#  'kavieng',
#  'tuatapere',
#  'petropavlovsk-kamchatskiy',
#  'lodwar',
#  'kendari',
#  'moses lake',
#  'maputo',
#  'coihaique',
#  'port hawkesbury',
#  'redlands',
#  'thinadhoo',
#  'jalu',
#  'kosh-agach',
#  'kawalu',
#  'port elizabeth',
#  'tokur',
#  'srednekolymsk',
#  'mandera',
#  'lagos',
#  'atasu',
#  'saldanha',
#  'bengkulu',
#  'teguise',
#  'nara',
#  'namatanai',
#  'ribas do rio pardo',
#  'berlevag',
#  'alta floresta',
#  'padang',
#  'mariinsk',
#  'tual',
#  'santo antonio do ica',
#  'gravelbourg',
#  'camacha',
#  'camocim',
#  'dawlatabad',
#  'borken',
#  'mayo',
#  'clyde river',
#  'djambala',
#  'mrirt',
#  'sorland',
#  'tsogni',
#  'cabo san lucas',
#  'halalo',
#  'basco',
#  'rovaniemi',
#  'constantine',
#  'yanam',
#  'rio bueno',
#  'kayerkan',
#  'ahipara',
#  'semey',
#  'brae',
#  'yerofey pavlovich',
#  'mindyak',
#  'tautira',
#  'bayji',
#  'reconquista',
#  'booue',
#  'tommot',
#  'shimoda',
#  'tura',
#  'ginda',
#  'sao joao da barra',
#  'kishi',
#  'nyimba',
#  'meulaboh',
#  'tezu',
#  'scarborough',
#  'singaraja',
#  'dien bien',
#  'port lincoln',
#  'dondo',
#  'fairbanks',
#  'kahului',
#  'opuwo',
#  'hami',
#  'ryotsu',
#  'severo-kurilsk',
#  'huaicheng',
#  'azul',
#  'khabary',
#  'tianpeng',
#  'gamboula',
#  'sangar',
#  'gornopravdinsk',
#  'fort nelson',
#  'dipkarpaz',
#  'am timan',
#  'mullaitivu',
#  'nouakchott',
#  'umm lajj',
#  'arlit',
#  'chandbali',
#  'iracoubo',
#  'norden',
#  'san luis',
#  'sao caetano de odivelas',
#  'muros',
#  'trairi',
#  'tahe',
#  'antsohihy',
#  'san rafael del sur',
#  'khandyga',
#  'lucea',
#  'port hedland',
#  'tondano',
#  'motygino',
#  'villa elisa',
#  'mayahi',
#  'sebezh',
#  'atbasar',
#  'margate',
#  'rodrigues alves',
#  'bauta',
#  'kerrville',
#  'alofi',
#  'phalombe',
#  'ca mau',
#  'priupskiy',
#  'saint-honore',
#  'torbay',
#  'manacapuru',
#  'itambacuri',
#  'kurilsk',
#  'sapouy',
#  'cabatuan',
#  'ceres',
#  'sao miguel do araguaia',
#  'yermolayevo',
#  'along',
#  'gevrai',
#  'salalah',
#  'prado',
#  'chokurdakh',
#  'tekeli',
#  'urucara',
#  'belyy yar',
#  'holzwickede',
#  'tawnat',
#  'chapais',
#  'khandbari',
#  'pendleton',
#  'zistersdorf',
#  'santa juliana',
#  'kingaroy',
#  'dhidhdhoo',
#  'port augusta',
#  'mys shmidta',
#  'muli',
#  'katsuura',
#  'cabedelo',
#  'carballo',
#  'petawawa',
#  'soure',
#  'turukhansk',
#  'valparaiso',
#  'bathsheba',
#  'bukachacha',
#  'broken hill',
#  'aklavik',
#  'morant bay',
#  'keti bandar',
#  'tinjah',
#  'ghanzi',
#  'cap malheureux',
#  'uhlove',
#  'maine-soroa',
#  'maniitsoq',
#  'wageningen',
#  'talnakh',
#  'mahadday weyne',
#  'huazolotitlan',
#  'sobolevo',
#  'znamenskoye',
#  'urengoy',
#  'ternate',
#  'somerset east',
#  'constitucion',
#  'babanusah',
#  'turbat',
#  'orangeburg',
#  'byron bay',
#  'lobito',
#  'lata',
#  'pemangkat',
#  'yatou',
#  'tawkar',
#  'skalistyy',
#  'atherton',
#  'krasnyy yar',
#  'macau',
#  'cherskiy',
#  'ust-ishim',
#  'mindelo',
#  'karratha',
#  'zhigansk',
#  'pacific grove',
#  'warqla',
#  'maracana',
#  'broome',
#  'bilma',
#  'barkhan',
#  'sentyabrskiy',
#  'sikonge',
#  'marsa matruh',
#  'nabire',
#  'aykhal',
#  'senmonorom',
#  'beisfjord',
#  'lazaro cardenas',
#  'lufilufi',
#  'bonavista',
#  'oranjestad',
#  'cockburn town',
#  'ewa beach',
#  'krasnoselkup',
#  'general roca',
#  'cervo',
#  'labutta',
#  'mahajanga',
#  'puerto escondido',
#  'lorengau',
#  'belaya gora',
#  'ambon',
#  'voyinka',
#  'rocha',
#  'shimsk',
#  'nanortalik',
#  'swan hill',
#  'beyneu',
#  'qasigiannguit',
#  'ganzhou',
#  'anadyr',
#  'baringo',
#  'kegayli',
#  'natal',
#  'pisco',
#  'yarkovo',
#  'el alto',
#  'morgan city',
#  'ngukurr',
#  'gawan',
#  'zapolyarnyy',
#  'guangyuan',
#  'nipawin',
#  'itarema',
#  'bhikangaon',
#  'nikolayevsk-na-amure',
#  'newton',
#  'tambovka',
#  'rocky mountain house',
#  'lipari',
#  'osakarovka',
#  'asfi',
#  'malanje',
#  'karakendzha',
#  'cumanayagua',
#  'novita',
#  'puerto carreno',
#  'maningrida',
#  'kuusamo',
#  'hualmay',
#  'lubango',
#  'touros',
#  'the valley',
#  'hachinohe',
#  'najran',
#  'alta gracia',
#  'banfora',
#  'chagda',
#  'abnub',
#  'samalaeulu',
#  'tsihombe',
#  'garowe',
#  'villa guerrero',
#  'saleaula',
#  'lahad datu',
#  'marcona',
#  'carutapera',
#  'samarai',
#  'usakos',
#  'oranjemund',
#  'north myrtle beach',
#  'olavarria',
#  'karlskrona',
#  'chikoy',
#  'ifakara',
#  'kahta',
#  'brumado',
#  'knin',
#  'arona',
#  'candido mendes',
#  'souillac',
#  'imperia',
#  'sataua',
#  'port blair',
#  'seddon',
#  'mount pleasant',
#  'sur',
#  'beloha',
#  'kabompo',
#  'bandarbeyla',
#  'coquimbo',
#  'temerloh',
#  'yeppoon',
#  'adrar',
#  'zlatoustovsk',
#  'izumo',
#  'balikpapan',
#  'poum',
#  'fare',
#  'miranorte',
#  'inhambane',
#  'leshukonskoye',
#  'san jose',
#  'zyryanka',
#  'baiyin',
#  'buala',
#  'playa del carmen',
#  'makakilo city',
#  'hofn',
#  'kuche',
#  'sukhobezvodnoye',
#  'san rafael',
#  'faya',
#  'horlivka',
#  'minab',
#  'lerwick',
#  'vao',
#  'umzimvubu',
#  'westport',
#  'bozoum',
#  'luwuk',
#  'bollnas',
#  'gedinne',
#  'khavarion',
#  'cairo',
#  'lourdes',
#  'buraydah',
#  'baay',
#  'tefe',
#  'jardim',
#  'pushkinskiye gory',
#  'cap-aux-meules',
#  'marzuq',
#  'tawang',
#  'kenai',
#  'stykkisholmur',
#  'abaza',
#  'sola',
#  'nguru',
#  'vrises',
#  'mahmudabad',
#  'miramar',
#  'hamilton',
#  'raga',
#  'millington',
#  'caravelas',
#  'vardo',
#  'paamiut',
#  'mvangue',
#  'varnsdorf',
#  'emba',
#  'kununurra',
#  'ust-kamchatsk',
#  'cascais',
#  'kalabo',
#  'codajas',
#  'progreso',
#  'aswan',
#  'aflu',
#  'sonegaon',
#  'santa rosa',
#  'ambodifototra',
#  'bereda',
#  'asau',
#  'klembivka',
#  'yunjinghong',
#  'san jeronimo',
#  'rosarito']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=6bbc6f9aa8c2d78e5b37d1a8c9cd4e68&units=imperial&q='

# %%
# This creates a loop that pulls out the weather data for each city name in the list.
weather=np.array([])
data = ()

# set up lists to hold response info
lat = []
temp = []
cloudiness = []
country = []
humidity =[]
lat =[]
lng = []
temp = []
wind_speed = []
city_name = []
index_counter = 0
set_counter = 1


for index, city in enumerate(cities, start =1):
        
    try:
        response = requests.get(query_url + city).json()
        
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        
        if index_counter >49:
            index_counter = 0
            set_counter = set_counter +1
            
        else:
            index_counter = index_counter + 1
            
        print(f"Processing city {index_counter} of Set {set_counter} : {city}")   
    
    except (KeyError, IndexError):
        print ("Error - skip.")

print("Done")
# Out:
# Processing city 1 of Set 1 : port hardy
# Processing city 2 of Set 1 : rikitea
# Processing city 3 of Set 1 : fonte boa
# Processing city 4 of Set 1 : batagay-alyta
# Processing city 5 of Set 1 : mataura
# Processing city 6 of Set 1 : ancud
# Processing city 7 of Set 1 : albany
# Processing city 8 of Set 1 : rawson
# Processing city 9 of Set 1 : henties bay
# Processing city 10 of Set 1 : dickinson
# Processing city 11 of Set 1 : butaritari
# Processing city 12 of Set 1 : saint-philippe
# Error - skip.
# Processing city 13 of Set 1 : bredasdorp
# Processing city 14 of Set 1 : upernavik
# Error - skip.
# Processing city 15 of Set 1 : saint-pierre
# Processing city 16 of Set 1 : punta arenas
# Processing city 17 of Set 1 : ribeira grande
# Processing city 18 of Set 1 : georgetown
# Processing city 19 of Set 1 : hobart
# Processing city 20 of Set 1 : ushuaia
# Processing city 21 of Set 1 : mahebourg
# Processing city 22 of Set 1 : puerto ayora
# Processing city 23 of Set 1 : rio gallegos
# Processing city 24 of Set 1 : kibaya
# Processing city 25 of Set 1 : cotonou
# Processing city 26 of Set 1 : norman wells
# Processing city 27 of Set 1 : gweta
# Processing city 28 of Set 1 : bontang
# Error - skip.
# Processing city 29 of Set 1 : longyearbyen
# Processing city 30 of Set 1 : avera
# Processing city 31 of Set 1 : lusaka
# Processing city 32 of Set 1 : dikson
# Processing city 33 of Set 1 : qaanaaq
# Processing city 34 of Set 1 : mpika
# Error - skip.
# Processing city 35 of Set 1 : saskylakh
# Processing city 36 of Set 1 : irati
# Processing city 37 of Set 1 : ostrovnoy
# Processing city 38 of Set 1 : vanimo
# Processing city 39 of Set 1 : nome
# Error - skip.
# Processing city 40 of Set 1 : niono
# Processing city 41 of Set 1 : yellowknife
# Processing city 42 of Set 1 : hermanus
# Processing city 43 of Set 1 : nioro
# Processing city 44 of Set 1 : bijar
# Processing city 45 of Set 1 : ponta do sol
# Processing city 46 of Set 1 : rock sound
# Processing city 47 of Set 1 : mount gambier
# Error - skip.
# Processing city 48 of Set 1 : verkh-usugli
# Processing city 49 of Set 1 : siguiri
# Processing city 50 of Set 1 : port-gentil
# Processing city 0 of Set 2 : acarau
# Processing city 1 of Set 2 : tiksi
# Processing city 2 of Set 2 : port alfred
# Processing city 3 of Set 2 : kindu
# Processing city 4 of Set 2 : claresholm
# Processing city 5 of Set 2 : faanui
# Processing city 6 of Set 2 : cape town
# Processing city 7 of Set 2 : ilam
# Processing city 8 of Set 2 : muriwai beach
# Processing city 9 of Set 2 : arraial do cabo
# Processing city 10 of Set 2 : portland
# Processing city 11 of Set 2 : sibolga
# Processing city 12 of Set 2 : bambanglipuro
# Processing city 13 of Set 2 : gobabis
# Processing city 14 of Set 2 : lebu
# Processing city 15 of Set 2 : sao sebastiao
# Processing city 16 of Set 2 : okhotsk
# Processing city 17 of Set 2 : corowa
# Processing city 18 of Set 2 : west bay
# Processing city 19 of Set 2 : thompson
# Processing city 20 of Set 2 : jamestown
# Processing city 21 of Set 2 : hilo
# Processing city 22 of Set 2 : tasiilaq
# Error - skip.
# Processing city 23 of Set 2 : dobbs ferry
# Processing city 24 of Set 2 : mirabad
# Processing city 25 of Set 2 : port macquarie
# Processing city 26 of Set 2 : san patricio
# Processing city 27 of Set 2 : vaini
# Processing city 28 of Set 2 : aloleng
# Processing city 29 of Set 2 : antofagasta
# Error - skip.
# Error - skip.
# Processing city 30 of Set 2 : saquena
# Processing city 31 of Set 2 : vilyuysk
# Processing city 32 of Set 2 : codrington
# Processing city 33 of Set 2 : nemuro
# Processing city 34 of Set 2 : vila franca do campo
# Processing city 35 of Set 2 : nandigama
# Processing city 36 of Set 2 : busselton
# Error - skip.
# Processing city 37 of Set 2 : bubaque
# Processing city 38 of Set 2 : mar del plata
# Processing city 39 of Set 2 : nelson bay
# Processing city 40 of Set 2 : avarua
# Processing city 41 of Set 2 : russell
# Processing city 42 of Set 2 : lannion
# Processing city 43 of Set 2 : abu dhabi
# Processing city 44 of Set 2 : kamaishi
# Processing city 45 of Set 2 : ust-kalmanka
# Processing city 46 of Set 2 : pitimbu
# Processing city 47 of Set 2 : usogorsk
# Processing city 48 of Set 2 : leningradskiy
# Processing city 49 of Set 2 : kaitangata
# Processing city 50 of Set 2 : kloulklubed
# Processing city 0 of Set 3 : roma
# Processing city 1 of Set 3 : goderich
# Processing city 2 of Set 3 : tynda
# Processing city 3 of Set 3 : santander
# Processing city 4 of Set 3 : dalvik
# Processing city 5 of Set 3 : columbus
# Processing city 6 of Set 3 : coxim
# Processing city 7 of Set 3 : bambous virieux
# Processing city 8 of Set 3 : luderitz
# Processing city 9 of Set 3 : kodiak
# Processing city 10 of Set 3 : castro
# Processing city 11 of Set 3 : san policarpo
# Processing city 12 of Set 3 : cidreira
# Processing city 13 of Set 3 : sharlyk
# Processing city 14 of Set 3 : la asuncion
# Processing city 15 of Set 3 : havre-saint-pierre
# Processing city 16 of Set 3 : imbituba
# Processing city 17 of Set 3 : barrow
# Processing city 18 of Set 3 : atuona
# Processing city 19 of Set 3 : sepolno krajenskie
# Processing city 20 of Set 3 : labuhan
# Processing city 21 of Set 3 : bethel
# Processing city 22 of Set 3 : tuktoyaktuk
# Processing city 23 of Set 3 : saint-georges
# Processing city 24 of Set 3 : naze
# Processing city 25 of Set 3 : sandane
# Processing city 26 of Set 3 : takoradi
# Processing city 27 of Set 3 : san cristobal
# Processing city 28 of Set 3 : hobyo
# Processing city 29 of Set 3 : flinders
# Error - skip.
# Processing city 30 of Set 3 : carepa
# Processing city 31 of Set 3 : vila velha
# Processing city 32 of Set 3 : kapaa
# Processing city 33 of Set 3 : punta alta
# Processing city 34 of Set 3 : nagato
# Processing city 35 of Set 3 : pangnirtung
# Processing city 36 of Set 3 : sitka
# Processing city 37 of Set 3 : new norfolk
# Processing city 38 of Set 3 : esperance
# Processing city 39 of Set 3 : namibe
# Processing city 40 of Set 3 : grindavik
# Processing city 41 of Set 3 : tocopilla
# Processing city 42 of Set 3 : nikolskoye
# Processing city 43 of Set 3 : hithadhoo
# Processing city 44 of Set 3 : waipawa
# Processing city 45 of Set 3 : mao
# Processing city 46 of Set 3 : sept-iles
# Processing city 47 of Set 3 : praia
# Processing city 48 of Set 3 : ilulissat
# Processing city 49 of Set 3 : chipinge
# Processing city 50 of Set 3 : havelock
# Processing city 0 of Set 4 : khatanga
# Processing city 1 of Set 4 : abashiri
# Processing city 2 of Set 4 : lagoa
# Error - skip.
# Processing city 3 of Set 4 : dubbo
# Processing city 4 of Set 4 : sydney
# Error - skip.
# Error - skip.
# Processing city 5 of Set 4 : raduzhnyy
# Processing city 6 of Set 4 : port shepstone
# Processing city 7 of Set 4 : puerto baquerizo moreno
# Processing city 8 of Set 4 : deputatskiy
# Processing city 9 of Set 4 : sawtell
# Processing city 10 of Set 4 : pevek
# Processing city 11 of Set 4 : maragogi
# Processing city 12 of Set 4 : abu samrah
# Processing city 13 of Set 4 : impfondo
# Error - skip.
# Processing city 14 of Set 4 : rafai
# Processing city 15 of Set 4 : moose factory
# Error - skip.
# Processing city 16 of Set 4 : mecca
# Processing city 17 of Set 4 : bluff
# Processing city 18 of Set 4 : sisimiut
# Processing city 19 of Set 4 : kruisfontein
# Processing city 20 of Set 4 : cayenne
# Processing city 21 of Set 4 : kumla
# Processing city 22 of Set 4 : puri
# Processing city 23 of Set 4 : east london
# Processing city 24 of Set 4 : verkhoyansk
# Processing city 25 of Set 4 : rohnert park
# Processing city 26 of Set 4 : batemans bay
# Processing city 27 of Set 4 : yar-sale
# Processing city 28 of Set 4 : mapiri
# Processing city 29 of Set 4 : manbij
# Processing city 30 of Set 4 : provideniya
# Processing city 31 of Set 4 : richards bay
# Processing city 32 of Set 4 : moba
# Processing city 33 of Set 4 : san vicente
# Processing city 34 of Set 4 : geraldton
# Processing city 35 of Set 4 : beaver dam
# Processing city 36 of Set 4 : college
# Processing city 37 of Set 4 : te anau
# Processing city 38 of Set 4 : airai
# Processing city 39 of Set 4 : idaho falls
# Processing city 40 of Set 4 : carnarvon
# Processing city 41 of Set 4 : mehamn
# Processing city 42 of Set 4 : lavrentiya
# Processing city 43 of Set 4 : san quintin
# Processing city 44 of Set 4 : kabalo
# Processing city 45 of Set 4 : plettenberg bay
# Processing city 46 of Set 4 : husavik
# Processing city 47 of Set 4 : narsaq
# Error - skip.
# Processing city 48 of Set 4 : victoria
# Processing city 49 of Set 4 : santa ines
# Processing city 50 of Set 4 : erzin
# Processing city 0 of Set 5 : santa rosalia
# Processing city 1 of Set 5 : hovd
# Processing city 2 of Set 5 : teguldet
# Processing city 3 of Set 5 : lompoc
# Processing city 4 of Set 5 : astana
# Processing city 5 of Set 5 : kijini
# Processing city 6 of Set 5 : klaksvik
# Processing city 7 of Set 5 : isangel
# Processing city 8 of Set 5 : haines junction
# Error - skip.
# Processing city 9 of Set 5 : kilindoni
# Processing city 10 of Set 5 : rafaela
# Processing city 11 of Set 5 : iqaluit
# Processing city 12 of Set 5 : arvika
# Processing city 13 of Set 5 : la ronge
# Processing city 14 of Set 5 : hasaki
# Processing city 15 of Set 5 : saint george
# Processing city 16 of Set 5 : shimanovsk
# Processing city 17 of Set 5 : fortuna
# Processing city 18 of Set 5 : farkhor
# Processing city 19 of Set 5 : matay
# Processing city 20 of Set 5 : chuy
# Processing city 21 of Set 5 : menongue
# Error - skip.
# Error - skip.
# Processing city 22 of Set 5 : brive-la-gaillarde
# Processing city 23 of Set 5 : kifri
# Error - skip.
# Processing city 24 of Set 5 : janakpur
# Processing city 25 of Set 5 : merauke
# Processing city 26 of Set 5 : kavieng
# Processing city 27 of Set 5 : tuatapere
# Processing city 28 of Set 5 : petropavlovsk-kamchatskiy
# Processing city 29 of Set 5 : lodwar
# Processing city 30 of Set 5 : kendari
# Processing city 31 of Set 5 : moses lake
# Processing city 32 of Set 5 : maputo
# Processing city 33 of Set 5 : coihaique
# Processing city 34 of Set 5 : port hawkesbury
# Processing city 35 of Set 5 : redlands
# Processing city 36 of Set 5 : thinadhoo
# Processing city 37 of Set 5 : jalu
# Processing city 38 of Set 5 : kosh-agach
# Processing city 39 of Set 5 : kawalu
# Processing city 40 of Set 5 : port elizabeth
# Processing city 41 of Set 5 : tokur
# Processing city 42 of Set 5 : srednekolymsk
# Processing city 43 of Set 5 : mandera
# Processing city 44 of Set 5 : lagos
# Processing city 45 of Set 5 : atasu
# Processing city 46 of Set 5 : saldanha
# Processing city 47 of Set 5 : bengkulu
# Processing city 48 of Set 5 : teguise
# Processing city 49 of Set 5 : nara
# Processing city 50 of Set 5 : namatanai
# Processing city 0 of Set 6 : ribas do rio pardo
# Processing city 1 of Set 6 : berlevag
# Processing city 2 of Set 6 : alta floresta
# Processing city 3 of Set 6 : padang
# Processing city 4 of Set 6 : mariinsk
# Processing city 5 of Set 6 : tual
# Processing city 6 of Set 6 : santo antonio do ica
# Processing city 7 of Set 6 : gravelbourg
# Processing city 8 of Set 6 : camacha
# Processing city 9 of Set 6 : camocim
# Processing city 10 of Set 6 : dawlatabad
# Processing city 11 of Set 6 : borken
# Processing city 12 of Set 6 : mayo
# Processing city 13 of Set 6 : clyde river
# Processing city 14 of Set 6 : djambala
# Error - skip.
# Processing city 15 of Set 6 : sorland
# Processing city 16 of Set 6 : tsogni
# Processing city 17 of Set 6 : cabo san lucas
# Error - skip.
# Processing city 18 of Set 6 : basco
# Processing city 19 of Set 6 : rovaniemi
# Processing city 20 of Set 6 : constantine
# Processing city 21 of Set 6 : yanam
# Processing city 22 of Set 6 : rio bueno
# Processing city 23 of Set 6 : kayerkan
# Processing city 24 of Set 6 : ahipara
# Processing city 25 of Set 6 : semey
# Processing city 26 of Set 6 : brae
# Processing city 27 of Set 6 : yerofey pavlovich
# Processing city 28 of Set 6 : mindyak
# Processing city 29 of Set 6 : tautira
# Processing city 30 of Set 6 : bayji
# Processing city 31 of Set 6 : reconquista
# Processing city 32 of Set 6 : booue
# Processing city 33 of Set 6 : tommot
# Processing city 34 of Set 6 : shimoda
# Processing city 35 of Set 6 : tura
# Processing city 36 of Set 6 : ginda
# Processing city 37 of Set 6 : sao joao da barra
# Processing city 38 of Set 6 : kishi
# Processing city 39 of Set 6 : nyimba
# Processing city 40 of Set 6 : meulaboh
# Processing city 41 of Set 6 : tezu
# Processing city 42 of Set 6 : scarborough
# Processing city 43 of Set 6 : singaraja
# Error - skip.
# Processing city 44 of Set 6 : port lincoln
# Processing city 45 of Set 6 : dondo
# Processing city 46 of Set 6 : fairbanks
# Processing city 47 of Set 6 : kahului
# Processing city 48 of Set 6 : opuwo
# Processing city 49 of Set 6 : hami
# Processing city 50 of Set 6 : ryotsu
# Processing city 0 of Set 7 : severo-kurilsk
# Processing city 1 of Set 7 : huaicheng
# Processing city 2 of Set 7 : azul
# Processing city 3 of Set 7 : khabary
# Processing city 4 of Set 7 : tianpeng
# Processing city 5 of Set 7 : gamboula
# Processing city 6 of Set 7 : sangar
# Processing city 7 of Set 7 : gornopravdinsk
# Processing city 8 of Set 7 : fort nelson
# Error - skip.
# Processing city 9 of Set 7 : am timan
# Error - skip.
# Processing city 10 of Set 7 : nouakchott
# Processing city 11 of Set 7 : umm lajj
# Processing city 12 of Set 7 : arlit
# Processing city 13 of Set 7 : chandbali
# Processing city 14 of Set 7 : iracoubo
# Processing city 15 of Set 7 : norden
# Processing city 16 of Set 7 : san luis
# Processing city 17 of Set 7 : sao caetano de odivelas
# Processing city 18 of Set 7 : muros
# Processing city 19 of Set 7 : trairi
# Processing city 20 of Set 7 : tahe
# Processing city 21 of Set 7 : antsohihy
# Processing city 22 of Set 7 : san rafael del sur
# Processing city 23 of Set 7 : khandyga
# Processing city 24 of Set 7 : lucea
# Processing city 25 of Set 7 : port hedland
# Processing city 26 of Set 7 : tondano
# Processing city 27 of Set 7 : motygino
# Processing city 28 of Set 7 : villa elisa
# Processing city 29 of Set 7 : mayahi
# Processing city 30 of Set 7 : sebezh
# Processing city 31 of Set 7 : atbasar
# Processing city 32 of Set 7 : margate
# Processing city 33 of Set 7 : rodrigues alves
# Processing city 34 of Set 7 : bauta
# Processing city 35 of Set 7 : kerrville
# Processing city 36 of Set 7 : alofi
# Processing city 37 of Set 7 : phalombe
# Processing city 38 of Set 7 : ca mau
# Processing city 39 of Set 7 : priupskiy
# Processing city 40 of Set 7 : saint-honore
# Processing city 41 of Set 7 : torbay
# Processing city 42 of Set 7 : manacapuru
# Processing city 43 of Set 7 : itambacuri
# Processing city 44 of Set 7 : kurilsk
# Processing city 45 of Set 7 : sapouy
# Processing city 46 of Set 7 : cabatuan
# Processing city 47 of Set 7 : ceres
# Processing city 48 of Set 7 : sao miguel do araguaia
# Processing city 49 of Set 7 : yermolayevo
# Processing city 50 of Set 7 : along
# Processing city 0 of Set 8 : gevrai
# Processing city 1 of Set 8 : salalah
# Processing city 2 of Set 8 : prado
# Processing city 3 of Set 8 : chokurdakh
# Processing city 4 of Set 8 : tekeli
# Processing city 5 of Set 8 : urucara
# Processing city 6 of Set 8 : belyy yar
# Processing city 7 of Set 8 : holzwickede
# Error - skip.
# Processing city 8 of Set 8 : chapais
# Processing city 9 of Set 8 : khandbari
# Processing city 10 of Set 8 : pendleton
# Processing city 11 of Set 8 : zistersdorf
# Processing city 12 of Set 8 : santa juliana
# Processing city 13 of Set 8 : kingaroy
# Processing city 14 of Set 8 : dhidhdhoo
# Processing city 15 of Set 8 : port augusta
# Error - skip.
# Processing city 16 of Set 8 : muli
# Processing city 17 of Set 8 : katsuura
# Processing city 18 of Set 8 : cabedelo
# Processing city 19 of Set 8 : carballo
# Processing city 20 of Set 8 : petawawa
# Processing city 21 of Set 8 : soure
# Processing city 22 of Set 8 : turukhansk
# Processing city 23 of Set 8 : valparaiso
# Processing city 24 of Set 8 : bathsheba
# Processing city 25 of Set 8 : bukachacha
# Processing city 26 of Set 8 : broken hill
# Processing city 27 of Set 8 : aklavik
# Processing city 28 of Set 8 : morant bay
# Processing city 29 of Set 8 : keti bandar
# Error - skip.
# Processing city 30 of Set 8 : ghanzi
# Processing city 31 of Set 8 : cap malheureux
# Processing city 32 of Set 8 : uhlove
# Processing city 33 of Set 8 : maine-soroa
# Processing city 34 of Set 8 : maniitsoq
# Processing city 35 of Set 8 : wageningen
# Processing city 36 of Set 8 : talnakh
# Error - skip.
# Error - skip.
# Processing city 37 of Set 8 : sobolevo
# Processing city 38 of Set 8 : znamenskoye
# Processing city 39 of Set 8 : urengoy
# Processing city 40 of Set 8 : ternate
# Processing city 41 of Set 8 : somerset east
# Processing city 42 of Set 8 : constitucion
# Error - skip.
# Processing city 43 of Set 8 : turbat
# Processing city 44 of Set 8 : orangeburg
# Processing city 45 of Set 8 : byron bay
# Processing city 46 of Set 8 : lobito
# Processing city 47 of Set 8 : lata
# Processing city 48 of Set 8 : pemangkat
# Processing city 49 of Set 8 : yatou
# Error - skip.
# Error - skip.
# Processing city 50 of Set 8 : atherton
# Processing city 0 of Set 9 : krasnyy yar
# Processing city 1 of Set 9 : macau
# Processing city 2 of Set 9 : cherskiy
# Processing city 3 of Set 9 : ust-ishim
# Processing city 4 of Set 9 : mindelo
# Processing city 5 of Set 9 : karratha
# Processing city 6 of Set 9 : zhigansk
# Processing city 7 of Set 9 : pacific grove
# Error - skip.
# Processing city 8 of Set 9 : maracana
# Processing city 9 of Set 9 : broome
# Processing city 10 of Set 9 : bilma
# Processing city 11 of Set 9 : barkhan
# Error - skip.
# Processing city 12 of Set 9 : sikonge
# Processing city 13 of Set 9 : marsa matruh
# Processing city 14 of Set 9 : nabire
# Processing city 15 of Set 9 : aykhal
# Error - skip.
# Processing city 16 of Set 9 : beisfjord
# Processing city 17 of Set 9 : lazaro cardenas
# Processing city 18 of Set 9 : lufilufi
# Processing city 19 of Set 9 : bonavista
# Processing city 20 of Set 9 : oranjestad
# Processing city 21 of Set 9 : cockburn town
# Processing city 22 of Set 9 : ewa beach
# Processing city 23 of Set 9 : krasnoselkup
# Processing city 24 of Set 9 : general roca
# Processing city 25 of Set 9 : cervo
# Error - skip.
# Processing city 26 of Set 9 : mahajanga
# Processing city 27 of Set 9 : puerto escondido
# Processing city 28 of Set 9 : lorengau
# Processing city 29 of Set 9 : belaya gora
# Processing city 30 of Set 9 : ambon
# Processing city 31 of Set 9 : voyinka
# Processing city 32 of Set 9 : rocha
# Processing city 33 of Set 9 : shimsk
# Processing city 34 of Set 9 : nanortalik
# Processing city 35 of Set 9 : swan hill
# Processing city 36 of Set 9 : beyneu
# Processing city 37 of Set 9 : qasigiannguit
# Processing city 38 of Set 9 : ganzhou
# Processing city 39 of Set 9 : anadyr
# Processing city 40 of Set 9 : baringo
# Error - skip.
# Processing city 41 of Set 9 : natal
# Processing city 42 of Set 9 : pisco
# Processing city 43 of Set 9 : yarkovo
# Processing city 44 of Set 9 : el alto
# Processing city 45 of Set 9 : morgan city
# Error - skip.
# Processing city 46 of Set 9 : gawan
# Processing city 47 of Set 9 : zapolyarnyy
# Processing city 48 of Set 9 : guangyuan
# Processing city 49 of Set 9 : nipawin
# Processing city 50 of Set 9 : itarema
# Processing city 0 of Set 10 : bhikangaon
# Processing city 1 of Set 10 : nikolayevsk-na-amure
# Processing city 2 of Set 10 : newton
# Processing city 3 of Set 10 : tambovka
# Processing city 4 of Set 10 : rocky mountain house
# Processing city 5 of Set 10 : lipari
# Processing city 6 of Set 10 : osakarovka
# Processing city 7 of Set 10 : asfi
# Processing city 8 of Set 10 : malanje
# Error - skip.
# Processing city 9 of Set 10 : cumanayagua
# Processing city 10 of Set 10 : novita
# Processing city 11 of Set 10 : puerto carreno
# Processing city 12 of Set 10 : maningrida
# Processing city 13 of Set 10 : kuusamo
# Processing city 14 of Set 10 : hualmay
# Processing city 15 of Set 10 : lubango
# Processing city 16 of Set 10 : touros
# Processing city 17 of Set 10 : the valley
# Processing city 18 of Set 10 : hachinohe
# Processing city 19 of Set 10 : najran
# Processing city 20 of Set 10 : alta gracia
# Processing city 21 of Set 10 : banfora
# Error - skip.
# Processing city 22 of Set 10 : abnub
# Error - skip.
# Error - skip.
# Processing city 23 of Set 10 : garowe
# Processing city 24 of Set 10 : villa guerrero
# Error - skip.
# Processing city 25 of Set 10 : lahad datu
# Error - skip.
# Processing city 26 of Set 10 : carutapera
# Processing city 27 of Set 10 : samarai
# Processing city 28 of Set 10 : usakos
# Processing city 29 of Set 10 : oranjemund
# Processing city 30 of Set 10 : north myrtle beach
# Processing city 31 of Set 10 : olavarria
# Processing city 32 of Set 10 : karlskrona
# Error - skip.
# Processing city 33 of Set 10 : ifakara
# Processing city 34 of Set 10 : kahta
# Processing city 35 of Set 10 : brumado
# Processing city 36 of Set 10 : knin
# Processing city 37 of Set 10 : arona
# Processing city 38 of Set 10 : candido mendes
# Processing city 39 of Set 10 : souillac
# Processing city 40 of Set 10 : imperia
# Error - skip.
# Processing city 41 of Set 10 : port blair
# Processing city 42 of Set 10 : seddon
# Processing city 43 of Set 10 : mount pleasant
# Processing city 44 of Set 10 : sur
# Processing city 45 of Set 10 : beloha
# Processing city 46 of Set 10 : kabompo
# Processing city 47 of Set 10 : bandarbeyla
# Processing city 48 of Set 10 : coquimbo
# Processing city 49 of Set 10 : temerloh
# Processing city 50 of Set 10 : yeppoon
# Processing city 0 of Set 11 : adrar
# Error - skip.
# Processing city 1 of Set 11 : izumo
# Processing city 2 of Set 11 : balikpapan
# Processing city 3 of Set 11 : poum
# Processing city 4 of Set 11 : fare
# Error - skip.
# Processing city 5 of Set 11 : inhambane
# Processing city 6 of Set 11 : leshukonskoye
# Processing city 7 of Set 11 : san jose
# Processing city 8 of Set 11 : zyryanka
# Processing city 9 of Set 11 : baiyin
# Processing city 10 of Set 11 : buala
# Processing city 11 of Set 11 : playa del carmen
# Processing city 12 of Set 11 : makakilo city
# Processing city 13 of Set 11 : hofn
# Error - skip.
# Processing city 14 of Set 11 : sukhobezvodnoye
# Processing city 15 of Set 11 : san rafael
# Processing city 16 of Set 11 : faya
# Processing city 17 of Set 11 : horlivka
# Processing city 18 of Set 11 : minab
# Processing city 19 of Set 11 : lerwick
# Processing city 20 of Set 11 : vao
# Error - skip.
# Processing city 21 of Set 11 : westport
# Processing city 22 of Set 11 : bozoum
# Processing city 23 of Set 11 : luwuk
# Processing city 24 of Set 11 : bollnas
# Processing city 25 of Set 11 : gedinne
# Error - skip.
# Processing city 26 of Set 11 : cairo
# Processing city 27 of Set 11 : lourdes
# Processing city 28 of Set 11 : buraydah
# Processing city 29 of Set 11 : baay
# Processing city 30 of Set 11 : tefe
# Processing city 31 of Set 11 : jardim
# Processing city 32 of Set 11 : pushkinskiye gory
# Processing city 33 of Set 11 : cap-aux-meules
# Processing city 34 of Set 11 : marzuq
# Processing city 35 of Set 11 : tawang
# Processing city 36 of Set 11 : kenai
# Processing city 37 of Set 11 : stykkisholmur
# Processing city 38 of Set 11 : abaza
# Processing city 39 of Set 11 : sola
# Processing city 40 of Set 11 : nguru
# Processing city 41 of Set 11 : vrises
# Processing city 42 of Set 11 : mahmudabad
# Processing city 43 of Set 11 : miramar
# Processing city 44 of Set 11 : hamilton
# Processing city 45 of Set 11 : raga
# Processing city 46 of Set 11 : millington
# Processing city 47 of Set 11 : caravelas
# Processing city 48 of Set 11 : vardo
# Processing city 49 of Set 11 : paamiut
# Processing city 50 of Set 11 : mvangue
# Processing city 0 of Set 12 : varnsdorf
# Processing city 1 of Set 12 : emba
# Processing city 2 of Set 12 : kununurra
# Error - skip.
# Processing city 3 of Set 12 : cascais
# Processing city 4 of Set 12 : kalabo
# Processing city 5 of Set 12 : codajas
# Processing city 6 of Set 12 : progreso
# Processing city 7 of Set 12 : aswan
# Error - skip.
# Processing city 8 of Set 12 : sonegaon
# Processing city 9 of Set 12 : santa rosa
# Error - skip.
# Processing city 10 of Set 12 : bereda
# Processing city 11 of Set 12 : asau
# Processing city 12 of Set 12 : klembivka
# Error - skip.
# Processing city 13 of Set 12 : san jeronimo
# Processing city 14 of Set 12 : rosarito
# Done

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data2_df = pd.DataFrame({
    "city": city_name,
    "country": country,
    "lat": lat,
    "temp": temp,
    "humidity": humidity,
    "cloudiness": cloudiness,
    "wind speed": wind_speed

})
   
weather_data2.count()
# Out:
# city          575
# country       575
# lat           575
# temp          575
# humidity      575
# cloudiness    575
# wind speed    575
# dtype: int64

# %%
weather_data2_df
# Out:
#               city country    lat   temp  humidity  cloudiness  wind speed
# 0       Port Hardy      CA  50.70  46.40        93          40        3.36
# 1          Rikitea      PF -23.12  74.23        75          36       14.99
# 2        Fonte Boa      BR  -2.50  98.60        35           6        3.02
# 3    Batagay-Alyta      RU  67.80  11.93        89           9        2.66
# 4          Mataura      NZ -46.19  37.76        95          31        0.96
# ..             ...     ...    ...    ...       ...         ...         ...
# 570         Bereda      ES  43.27  60.93        99          87        1.99
# 571           Asău      RO  46.43  61.00        92          37        2.19
# 572      Klembivka      UA  48.39  60.01        84          89        8.93
# 573   San Jerónimo      PE -11.95  63.73        30           2        2.10
# 574       Rosarito      MX  32.33  72.19        53           5        3.36
#
# [575 rows x 7 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# print(weather_data2_df[(city_name)].where(weather_data2_df[(humidity)] > 100))

h_humid_df = weather_data2_df[weather_data2_df['humidity'] > (100)]
h_humid_df
# Out:
# Empty DataFrame
# Columns: [city, country, lat, temp, humidity, cloudiness, wind speed]
# Index: []

# %%
# There are no cities with humidity greater than 100**


#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
