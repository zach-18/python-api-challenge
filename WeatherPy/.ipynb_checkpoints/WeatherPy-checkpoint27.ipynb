# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Installing citipy module
#!pip install citipy
from citipy import citipy

# Dependencies
import pandas as pd
import numpy as np
import requests
import json

from scipy import stats
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Google API Key
from api_keys import g_key
from api_keys import weather_api_key
from itertools import product
from itertools import permutations
# print (weather_api_key)

import scipy.stats as st

# %% [markdown]
# ## Generate Cities List

# %%
#**********Need to fix the limit, gives more than 500 values***************

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1600)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1600)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 650

# %%
cities
# Out:
# ['lompoc',
#  'saint-philippe',
#  'hobart',
#  'east london',
#  'cuamba',
#  'kara',
#  'briancon',
#  'verkh-usugli',
#  'komsomolskiy',
#  'kapaa',
#  'yucca valley',
#  'galveston',
#  'helong',
#  'hermanus',
#  'attawapiskat',
#  'cardenas',
#  'thinadhoo',
#  'busselton',
#  'alice springs',
#  'murgab',
#  'tsihombe',
#  'ushuaia',
#  'airai',
#  'atambua',
#  'burnie',
#  'domoni',
#  'fairbanks',
#  'bethel',
#  'mount gambier',
#  'port hardy',
#  'port alfred',
#  'xichang',
#  'cherskiy',
#  'neepawa',
#  'arraial do cabo',
#  'punta arenas',
#  'saint-pierre',
#  'pevek',
#  'butaritari',
#  'asau',
#  'saskylakh',
#  'inhambane',
#  'acari',
#  'atuona',
#  'doba',
#  'itoman',
#  'the pas',
#  'bur gabo',
#  'paramirim',
#  'zhanaozen',
#  'blackwater',
#  'samusu',
#  'tsaratanana',
#  'liwale',
#  'nanortalik',
#  'port elizabeth',
#  'hirna',
#  'albany',
#  'rikitea',
#  'taolanaro',
#  'capitan bado',
#  'shahrud',
#  'puerto ayora',
#  'naze',
#  'vaini',
#  'pascagoula',
#  'katobu',
#  'barrow',
#  'carnarvon',
#  'voh',
#  'avarua',
#  'hilo',
#  'vaitupu',
#  'constitucion',
#  'luderitz',
#  'klaksvik',
#  'yellowknife',
#  'ancud',
#  'jamestown',
#  'saleaula',
#  'mareeba',
#  'baie-saint-paul',
#  'cape town',
#  'ahumada',
#  'kinablangan',
#  'north bend',
#  'sitka',
#  'isangel',
#  'black river',
#  'katherine',
#  'darhan',
#  'sorland',
#  'olafsvik',
#  'ilheus',
#  'upernavik',
#  'zhanatas',
#  'leesburg',
#  'cayenne',
#  'martapura',
#  'sola',
#  'horta',
#  'vestmannaeyjar',
#  'trairi',
#  'tasiilaq',
#  'blois',
#  'pimenta bueno',
#  'vostok',
#  'georgetown',
#  'zhiryatino',
#  'esperance',
#  'deputatskiy',
#  'ruatoria',
#  'bluff',
#  'charters towers',
#  'gomez palacio',
#  'ust-kuyga',
#  'omboue',
#  'saint anthony',
#  'nizhneyansk',
#  'severo-kurilsk',
#  'quang ngai',
#  'san rafael',
#  'kaitangata',
#  'bilma',
#  'salalah',
#  'kahului',
#  'kibala',
#  'chapais',
#  'berezovyy',
#  'marzuq',
#  'palermo',
#  'umzimvubu',
#  'bambous virieux',
#  'tuktoyaktuk',
#  'grand river south east',
#  'dikson',
#  'opoczno',
#  'borlange',
#  'nuevitas',
#  'baganga',
#  'labuhan',
#  'dingle',
#  'mahebourg',
#  'caravelas',
#  'mogzon',
#  'beloha',
#  'provideniya',
#  'fukue',
#  'ust-kamchatsk',
#  'storforshei',
#  'lebu',
#  'damphu',
#  'shubarkuduk',
#  'palmer',
#  'marsabit',
#  'egvekinot',
#  'la macarena',
#  'qaanaaq',
#  'new norfolk',
#  'malindi',
#  'bredasdorp',
#  'marrakesh',
#  'nelson bay',
#  'necochea',
#  'mataura',
#  'havre-saint-pierre',
#  'quatre cocos',
#  'qasigiannguit',
#  'norman wells',
#  'santa ana',
#  'mar del plata',
#  'kavaratti',
#  'marabba',
#  'joshimath',
#  'aloleng',
#  'anloga',
#  'kamenka',
#  'curup',
#  'longyearbyen',
#  'geraldton',
#  'touros',
#  'berehomet',
#  'padang',
#  'bartica',
#  'aragarcas',
#  'cayeli',
#  'bonthe',
#  'ponta do sol',
#  'belushya guba',
#  'palabuhanratu',
#  'vestmanna',
#  'vung tau',
#  'kruisfontein',
#  'north port',
#  'pacific grove',
#  'banda aceh',
#  'aklavik',
#  'san patricio',
#  'castro',
#  'saldanha',
#  'ulaangom',
#  'ahipara',
#  'mumford',
#  'paamiut',
#  'alexander city',
#  'san vicente',
#  'candelaria',
#  'aipe',
#  'sargatskoye',
#  'fortuna',
#  'la ronge',
#  'fontenay-le-comte',
#  'tondano',
#  'vardo',
#  'chadiza',
#  'sorvag',
#  'nikolskoye',
#  'poopo',
#  'phalombe',
#  'marawi',
#  'montepuez',
#  'sao filipe',
#  'atar',
#  'languyan',
#  'tessalit',
#  'maria aurora',
#  'gisborne',
#  'saint george',
#  'turbat',
#  'karratha',
#  'krasnokamensk',
#  'saltillo',
#  'alexandria',
#  'hithadhoo',
#  'ribeira grande',
#  'adrar',
#  'faanui',
#  'damavand',
#  'ambilobe',
#  'barentsburg',
#  'kaihua',
#  'puerto madero',
#  'waingapu',
#  'vilnius',
#  'riohacha',
#  'svetlogorsk',
#  'roald',
#  'taburi',
#  'najran',
#  'cabo san lucas',
#  'coro',
#  'gao',
#  'tanout',
#  'songkhla',
#  'mys shmidta',
#  'xuddur',
#  'chokurdakh',
#  'gushikawa',
#  'cheuskiny',
#  'sentyabrskiy',
#  'grimari',
#  'narsaq',
#  'imeni poliny osipenko',
#  'amderma',
#  'zigong',
#  'college',
#  'chagda',
#  'chuy',
#  'vaitape',
#  'krumovgrad',
#  'visavadar',
#  'cedartown',
#  'grindavik',
#  'illoqqortoormiut',
#  'dalbandin',
#  'delijan',
#  'xining',
#  'kamenskoye',
#  'harper',
#  'sao joao da barra',
#  'chengdu',
#  'pangai',
#  'aflu',
#  'benguela',
#  'carahue',
#  'eskasem',
#  'talas',
#  'mergui',
#  'sal rei',
#  'nevesinje',
#  'fortuna foothills',
#  'meulaboh',
#  'banjar',
#  'ossora',
#  'kapoeta',
#  'talnakh',
#  'puertollano',
#  'twin falls',
#  'jacareacanga',
#  'cedar city',
#  'faya',
#  'antissa',
#  'hofn',
#  'pecos',
#  'hostivice',
#  'jaisalmer',
#  'lima',
#  'praia da vitoria',
#  'tautira',
#  'ostersund',
#  'maryborough',
#  'port moresby',
#  'kununurra',
#  'volchikha',
#  'neklyudovo',
#  'ballina',
#  'oistins',
#  'khatanga',
#  'tabou',
#  'rafraf',
#  'pangnirtung',
#  'aquiraz',
#  'muzhi',
#  'bengkulu',
#  'seymchan',
#  'olinda',
#  'mandalgovi',
#  'vila franca do campo',
#  'tuatapere',
#  'carutapera',
#  'blama',
#  'port blair',
#  'torbay',
#  'canutama',
#  'ahuimanu',
#  'nizhniy tsasuchey',
#  'turukhansk',
#  'hami',
#  'tiksi',
#  'westport',
#  'northam',
#  'tambul',
#  'victoria',
#  'kodiak',
#  'palu',
#  'dekoa',
#  'zhigansk',
#  'ligayan',
#  'bor',
#  'lorengau',
#  'souillac',
#  'marcona',
#  'yar-sale',
#  'mangan',
#  'kotelnikovo',
#  'clyde river',
#  'shelburne',
#  'buala',
#  'mimongo',
#  'barra do garcas',
#  'dickinson',
#  'balsas',
#  'bayir',
#  'vysokogornyy',
#  'aranos',
#  'namatanai',
#  'barawe',
#  'moron',
#  'mlimba',
#  'paradwip',
#  'codrington',
#  'thompson',
#  'long beach',
#  'tucuman',
#  'prachuap khiri khan',
#  'kuryk',
#  'xingyi',
#  'louisbourg',
#  'arman',
#  'broken hill',
#  'pak phanang',
#  'celestun',
#  'ati',
#  'tura',
#  'ixtacuixtla',
#  'cockburn town',
#  'ust-uda',
#  'salinopolis',
#  'asosa',
#  'vilyuysk',
#  'sao felix do xingu',
#  'ust-charyshskaya pristan',
#  'sistranda',
#  'gari',
#  'arica',
#  'cabedelo',
#  'a',
#  'san cristobal',
#  'maloshuyka',
#  'fereydun kenar',
#  'cidreira',
#  'lavrentiya',
#  'beyneu',
#  'hammerfest',
#  'luganville',
#  'shakiso',
#  'flinders',
#  'tombouctou',
#  'doka',
#  'husavik',
#  'feicheng',
#  'usinsk',
#  'teguldet',
#  'makokou',
#  'gamba',
#  'ajaccio',
#  'foz do iguacu',
#  'bichura',
#  'khandyga',
#  'szydlowiec',
#  'brewster',
#  'waipawa',
#  'suzu',
#  'soledade',
#  'coelho neto',
#  'noumea',
#  'lata',
#  'nantucket',
#  'lasa',
#  'eureka',
#  'kuche',
#  'susanville',
#  'krasnovishersk',
#  'raudeberg',
#  'gold coast',
#  'bayshore gardens',
#  'brookings',
#  'taoudenni',
#  'trat',
#  'puerto maldonado',
#  'abnub',
#  'cockburn harbour',
#  'mugan',
#  'daru',
#  'panguna',
#  'bathsheba',
#  'portland',
#  'hunza',
#  'hasaki',
#  'mehamn',
#  'maues',
#  'christchurch',
#  'ler',
#  'mufumbwe',
#  'tabialan',
#  'svetlyy',
#  'taicheng',
#  'marsa matruh',
#  'palaikastron',
#  'basco',
#  'okhotsk',
#  'wonthaggi',
#  'axim',
#  'ixtapa',
#  'barcelos',
#  'saint-georges',
#  'ostrovnoy',
#  'okha',
#  'darnah',
#  'pisco',
#  'takoradi',
#  'horsham',
#  'aksarayskiy',
#  'sembakung',
#  'winkler',
#  'brae',
#  'leiyang',
#  'oksfjord',
#  'nakhon sawan',
#  'colonial park',
#  'mahanoro',
#  'grand gaube',
#  'praia',
#  'pedernales',
#  'sinnamary',
#  'halalo',
#  'shaki',
#  'jangipur',
#  'maniitsoq',
#  'leningradskiy',
#  'babanusah',
#  'katsuura',
#  'nampula',
#  'anshun',
#  'schuttorf',
#  'roebourne',
#  'lazaro cardenas',
#  'manga',
#  'kholodnyy',
#  'taltal',
#  'mangai',
#  'hihifo',
#  'haines junction',
#  'nyurba',
#  'tilichiki',
#  'port-gentil',
#  'kemijarvi',
#  'nicoya',
#  'padre bernardo',
#  'trois-pistoles',
#  'hastings',
#  'bubaque',
#  'gigmoto',
#  'pauini',
#  'ust-nera',
#  'kavieng',
#  'venosa',
#  'pochutla',
#  'jhelum',
#  'peniche',
#  'irbeyskoye',
#  'hervey bay',
#  'paracatu',
#  'kita',
#  'nome',
#  'burley',
#  'banepa',
#  'espanola',
#  'lensk',
#  'viedma',
#  'tucumcari',
#  'sabang',
#  'aqtobe',
#  'medina',
#  'zalantun',
#  'aykhal',
#  'menomonie',
#  'kati',
#  'nanyang',
#  'samana',
#  'calama',
#  'savannah bight',
#  'murakami',
#  'sao miguel do araguaia',
#  'pangkalanbuun',
#  'zheleznodorozhnyy',
#  'robertsport',
#  'baruun-urt',
#  'eyl',
#  'bereda',
#  'lidkoping',
#  'ugoofaaru',
#  'kalemie',
#  'innisfail',
#  'evanston',
#  'novaya igirma',
#  'fort nelson',
#  'mosquera',
#  'kieta',
#  'harlingen',
#  'minab',
#  'wollongong',
#  'puchezh',
#  'whyalla',
#  'khani',
#  'karachi',
#  'karkaralinsk',
#  'skeldon',
#  'saint-paul',
#  'port-cartier',
#  'ende',
#  'byron bay',
#  'lagoa',
#  'hamilton',
#  'mount abu',
#  'goteborg',
#  'tabiauea',
#  'zaysan',
#  'port lincoln',
#  'kloulklubed',
#  'kulhudhuffushi',
#  'luban',
#  'bardiyah',
#  'togur',
#  'svetlaya',
#  'baykit',
#  'hopelchen',
#  'parabel',
#  'yeppoon',
#  'mingyue',
#  'namibe',
#  'saint-augustin',
#  'gadung',
#  'lesnoye',
#  'dandong',
#  'mount isa',
#  'trelew',
#  'madang',
#  'verkhnetulomskiy',
#  'skalistyy',
#  'santarem',
#  'coquimbo',
#  'harboore',
#  'tshela',
#  'imbituba',
#  'matam',
#  'bukachacha',
#  'tumannyy',
#  'kropotkin',
#  'yanam',
#  'conceicao do araguaia',
#  'vitim',
#  'lawrenceburg',
#  'dunda',
#  'jeremie',
#  'ascension',
#  'yarmouth',
#  'beberibe',
#  'malartic',
#  'acapulco',
#  'ternate',
#  'udachnyy',
#  'tabuk',
#  'beringovskiy',
#  'vielsalm',
#  'galle',
#  'wulanhaote',
#  'kyaikkami',
#  'kasongo-lunda',
#  'nikolayevsk-na-amure',
#  'maryville',
#  'le port',
#  'ilulissat',
#  'lisala',
#  'ha giang',
#  'itarema',
#  'kidal',
#  'tall kayf',
#  'foumban',
#  'dunayivtsi',
#  'aksu',
#  'tahoua',
#  'sambava',
#  'sungaipenuh',
#  'aksarka',
#  'baherden',
#  'xingcheng',
#  'tawkar',
#  'bolungarvik',
#  'manicore']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=6bbc6f9aa8c2d78e5b37d1a8c9cd4e68&units=imperial&q='

# %%
# This creates a loop that pulls out the weather data for each city name in the list.
weather=np.array([])
data = ()

# set up lists to hold response info
lat = []
temp = []
cloudiness = []
country = []
humidity =[]
lat =[]
lng = []
temp = []
wind_speed = []
city_name = []
index_counter = 0
set_counter = 1


for index, city in enumerate(cities, start =1):
        
    try:
        response = requests.get(query_url + city).json()
        
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        
        if index_counter >49:
            index_counter = 0
            set_counter = set_counter +1
            
        else:
            index_counter = index_counter + 1
            
        print(f"Processing city {index_counter} of Set {set_counter} : {city}")   
    
    except (KeyError, IndexError):
        print ("Error - skip.")

print("Done")
# Out:
# Processing city 1 of Set 1 : lompoc
# Processing city 2 of Set 1 : saint-philippe
# Processing city 3 of Set 1 : hobart
# Processing city 4 of Set 1 : east london
# Processing city 5 of Set 1 : cuamba
# Processing city 6 of Set 1 : kara
# Processing city 7 of Set 1 : briancon
# Processing city 8 of Set 1 : verkh-usugli
# Processing city 9 of Set 1 : komsomolskiy
# Processing city 10 of Set 1 : kapaa
# Processing city 11 of Set 1 : yucca valley
# Processing city 12 of Set 1 : galveston
# Processing city 13 of Set 1 : helong
# Processing city 14 of Set 1 : hermanus
# Error - skip.
# Processing city 15 of Set 1 : cardenas
# Processing city 16 of Set 1 : thinadhoo
# Processing city 17 of Set 1 : busselton
# Processing city 18 of Set 1 : alice springs
# Processing city 19 of Set 1 : murgab
# Error - skip.
# Processing city 20 of Set 1 : ushuaia
# Processing city 21 of Set 1 : airai
# Processing city 22 of Set 1 : atambua
# Processing city 23 of Set 1 : burnie
# Processing city 24 of Set 1 : domoni
# Processing city 25 of Set 1 : fairbanks
# Processing city 26 of Set 1 : bethel
# Processing city 27 of Set 1 : mount gambier
# Processing city 28 of Set 1 : port hardy
# Processing city 29 of Set 1 : port alfred
# Processing city 30 of Set 1 : xichang
# Processing city 31 of Set 1 : cherskiy
# Processing city 32 of Set 1 : neepawa
# Processing city 33 of Set 1 : arraial do cabo
# Processing city 34 of Set 1 : punta arenas
# Processing city 35 of Set 1 : saint-pierre
# Processing city 36 of Set 1 : pevek
# Processing city 37 of Set 1 : butaritari
# Processing city 38 of Set 1 : asau
# Processing city 39 of Set 1 : saskylakh
# Processing city 40 of Set 1 : inhambane
# Processing city 41 of Set 1 : acari
# Processing city 42 of Set 1 : atuona
# Processing city 43 of Set 1 : doba
# Processing city 44 of Set 1 : itoman
# Processing city 45 of Set 1 : the pas
# Error - skip.
# Processing city 46 of Set 1 : paramirim
# Processing city 47 of Set 1 : zhanaozen
# Processing city 48 of Set 1 : blackwater
# Processing city 42 of Set 4 : fontenay-le-comte
# Processing city 43 of Set 4 : tondano
# Processing city 44 of Set 4 : vardo
# Processing city 45 of Set 4 : chadiza
# Error - skip.
# Processing city 46 of Set 4 : nikolskoye
# Processing city 47 of Set 4 : poopo
# Processing city 48 of Set 4 : phalombe
# Processing city 49 of Set 4 : marawi
# Processing city 50 of Set 4 : montepuez
# Processing city 0 of Set 5 : sao filipe
# Processing city 1 of Set 5 : atar
# Processing city 2 of Set 5 : languyan
# Processing city 3 of Set 5 : tessalit
# Processing city 4 of Set 5 : maria aurora
# Processing city 5 of Set 5 : gisborne
# Processing city 6 of Set 5 : saint george
# Processing city 7 of Set 5 : turbat
# Processing city 8 of Set 5 : karratha
# Processing city 9 of Set 5 : krasnokamensk
# Processing city 10 of Set 5 : saltillo
# Processing city 11 of Set 5 : alexandria
# Processing city 12 of Set 5 : hithadhoo
# Processing city 13 of Set 5 : ribeira grande
# Processing city 14 of Set 5 : adrar
# Processing city 15 of Set 5 : faanui
# Processing city 16 of Set 5 : damavand
# Processing city 17 of Set 5 : ambilobe
# Error - skip.
# Processing city 18 of Set 5 : kaihua
# Processing city 19 of Set 5 : puerto madero
# Processing city 20 of Set 5 : waingapu
# Processing city 21 of Set 5 : vilnius
# Processing city 22 of Set 5 : riohacha
# Processing city 23 of Set 5 : svetlogorsk
# Processing city 24 of Set 5 : roald
# Error - skip.
# Processing city 25 of Set 5 : najran
# Processing city 26 of Set 5 : cabo san lucas
# Processing city 27 of Set 5 : coro
# Processing city 28 of Set 5 : gao
# Processing city 29 of Set 5 : tanout
# Processing city 30 of Set 5 : songkhla
# Error - skip.
# Processing city 31 of Set 5 : xuddur
# Processing city 32 of Set 5 : chokurdakh
# Processing city 33 of Set 5 : gushikawa
# Error - skip.
# Error - skip.
# Error - skip.
# Processing city 34 of Set 5 : narsaq
# Processing city 35 of Set 5 : imeni poliny osipenko
# Error - skip.
# Processing city 36 of Set 5 : zigong
# Processing city 37 of Set 5 : college
# Error - skip.
# Processing city 38 of Set 5 : chuy
# Processing city 39 of Set 5 : vaitape
# Processing city 40 of Set 5 : krumovgrad
# Processing city 41 of Set 5 : visavadar
# Processing city 42 of Set 5 : cedartown
# Processing city 43 of Set 5 : grindavik
# Error - skip.
# Processing city 44 of Set 5 : dalbandin
# Processing city 45 of Set 5 : delijan
# Processing city 46 of Set 5 : xining
# Error - skip.
# Processing city 47 of Set 5 : harper
# Processing city 48 of Set 5 : sao joao da barra
# Processing city 49 of Set 5 : chengdu
# Processing city 50 of Set 5 : pangai
# Error - skip.
# Processing city 0 of Set 6 : benguela
# Processing city 1 of Set 6 : carahue
# Error - skip.
# Processing city 2 of Set 6 : talas
# Error - skip.
# Processing city 3 of Set 6 : sal rei
# Processing city 4 of Set 6 : nevesinje
# Processing city 5 of Set 6 : fortuna foothills
# Processing city 6 of Set 6 : meulaboh
# Processing city 7 of Set 6 : banjar
# Processing city 8 of Set 6 : ossora
# Processing city 9 of Set 6 : kapoeta
# Processing city 49 of Set 11 : dunda
# Processing city 50 of Set 11 : jeremie
# Processing city 0 of Set 12 : ascension
# Processing city 1 of Set 12 : yarmouth
# Processing city 2 of Set 12 : beberibe
# Processing city 3 of Set 12 : malartic
# Processing city 4 of Set 12 : acapulco
# Processing city 5 of Set 12 : ternate
# Processing city 6 of Set 12 : udachnyy
# Processing city 7 of Set 12 : tabuk
# Processing city 8 of Set 12 : beringovskiy
# Processing city 9 of Set 12 : vielsalm
# Processing city 10 of Set 12 : galle
# Error - skip.
# Processing city 11 of Set 12 : kyaikkami
# Processing city 12 of Set 12 : kasongo-lunda
# Processing city 13 of Set 12 : nikolayevsk-na-amure
# Processing city 14 of Set 12 : maryville
# Processing city 15 of Set 12 : le port
# Processing city 16 of Set 12 : ilulissat
# Processing city 17 of Set 12 : lisala
# Processing city 18 of Set 12 : ha giang
# Processing city 19 of Set 12 : itarema
# Processing city 20 of Set 12 : kidal
# Processing city 21 of Set 12 : tall kayf
# Processing city 22 of Set 12 : foumban
# Error - skip.
# Processing city 23 of Set 12 : aksu
# Processing city 24 of Set 12 : tahoua
# Processing city 25 of Set 12 : sambava
# Processing city 26 of Set 12 : sungaipenuh
# Processing city 27 of Set 12 : aksarka
# Processing city 28 of Set 12 : baherden
# Processing city 29 of Set 12 : xingcheng
# Error - skip.
# Error - skip.
# Processing city 30 of Set 12 : manicore
# Done

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data2_df = pd.DataFrame({
    "city": city_name,
    "country": country,
    "lat": lat,
    "lng": lng,
    "temp": temp,
    "humidity": humidity,
    "cloudiness": cloudiness,
    "wind speed": wind_speed

})
   
weather_data2_df.count()
# Out:
# city          591
# country       591
# lat           591
# lng           591
# temp          591
# humidity      591
# cloudiness    591
# wind speed    591
# dtype: int64

# %%
weather_data2_df
# Out:
#                city country    lat    lng   temp  humidity  cloudiness  \
# 0            Lompoc      US  34.64  34.64  54.81        66           1
# 1    Saint-Philippe      RE -21.36 -21.36  72.30        73          42
# 2            Hobart      AU -42.88 -42.88  41.34        93          75
# 3       East London      ZA -33.02 -33.02  64.40        55           0
# 4            Cuamba      MZ -14.80 -14.80  83.37        48          58
# ..              ...     ...    ...    ...    ...       ...         ...
# 586    Sungai Penuh      ID  -2.08  -2.08  66.90        95         100
# 587         Aksarka      RU  66.56  66.56  41.65        88         100
# 588         Baharly      TM  38.44  38.44  63.68        24           0
# 589       Xingcheng      CN  40.62  40.62  46.15        46          65
# 590        Manicoré      BR  -5.81  -5.81  98.91        36          26
#
#      wind speed
# 0          3.36
# 1          3.36
# 2          6.93
# 3         25.28
# 4          7.76
# ..          ...
# 586        0.85
# 587       12.21
# 588        8.03
# 589       10.83
# 590        3.09
#
# [591 rows x 8 columns]

# %%
weather_data2_df.to_csv("output_data/cities.csv", index = False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# print(weather_data2_df[(city_name)].where(weather_data2_df[(humidity)] > 100))

h_humid_df = weather_data2_df[weather_data2_df['humidity'] > (100)]
h_humid_df
# Out:
# Empty DataFrame
# Columns: [city, country, lat, lng, temp, humidity, cloudiness, wind speed]
# Index: []

# %%
# There are no cities with humidity greater than 100**


#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.title("Latitude vs. Temperature Plot")
plt.xlabel("Latitude (deg)")
plt.ylabel("Temperature (F)")

plt.scatter(lat,temp)
plt.show(lat,temp)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.title("Latitude vs. Humidity Plot")
plt.xlabel("Latitude (deg)")
plt.ylabel("Humidity (%)")

plt.scatter(lat,humidity)
plt.show(lat,humidity)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.title("Latitude vs. Cloudiness Plot")
plt.xlabel("Latitude (deg)")
plt.ylabel("Cloudiness (%)")

plt.scatter(lat,cloudiness)
plt.show(lat,cloudiness)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.title("Latitude vs. Wind Speed Plot")
plt.xlabel("Latitude (deg)")
plt.ylabel("Wind Speed (mph)")

plt.scatter(lat,wind_speed)
plt.show(lat,wind_speed)

# %% [markdown]
# ## Linear Regression

# %%
north = weather_data2_df['lat']>0
print(north.head())

south = weather_data2_df['lat']<0
print(south.head())
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: lat, dtype: bool
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# Name: lat, dtype: bool

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
weather_datan_df = weather_data2_df[north]
print(weather_datan_df.tail())

weather_datas_df = weather_data2_df[south]
print(weather_datas_df.tail())
# Out:
#           city country    lat    lng    temp  humidity  cloudiness  wind speed
# 583       Aksu      CN  41.12  41.12   55.26        36          43        5.39
# 584     Tahoua      NE  14.89  14.89  100.58        12           0        1.32
# 587    Aksarka      RU  66.56  66.56   41.65        88         100       12.21
# 588    Baharly      TM  38.44  38.44   63.68        24           0        8.03
# 589  Xingcheng      CN  40.62  40.62   46.15        46          65       10.83
#              city country    lat    lng   temp  humidity  cloudiness  \
# 575       Le Port      RE -20.94 -20.94  69.96        73          35
# 579       Itarema      BR  -2.92  -2.92  87.91        51          22
# 585       Sambava      MG -14.27 -14.27  76.10        77           5
# 586  Sungai Penuh      ID  -2.08  -2.08  66.90        95         100
# 590      Manicoré      BR  -5.81  -5.81  98.91        36          26
#
#      wind speed
# 575       14.99
# 579       19.24
# 585        8.23
# 586        0.85
# 590        3.09

# %%
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")



x = weather_datan_df["lat"]
y = weather_datan_df["temp"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Temp Max (F)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is -0.86
# The r-squared is: 0.7393494051059537
# The regression equation is: y = -0.91x + 93.86

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")



x = weather_datas_df["lat"]
y = weather_datas_df["temp"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Temp Max (F)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.74
# The r-squared is: 0.5412650876901054
# The regression equation is: y = 0.75x + 88.49

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")



x = weather_datan_df["lat"]
y = weather_datan_df["humidity"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.24
# The r-squared is: 0.059794209179420924
# The regression equation is: y = 0.27x + 60.51

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")



x = weather_datas_df["lat"]
y = weather_datas_df["humidity"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.03
# The r-squared is: 0.0009525820797143914
# The regression equation is: y = 0.05x + 66.23

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude (deg)")
plt.ylabel("Cloudiness (%)")



x = weather_datan_df["lat"]
y = weather_datan_df["cloudiness"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.08
# The r-squared is: 0.006382851487900219
# The regression equation is: y = 0.15x + 45.98

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude (deg)")
plt.ylabel("Cloudiness (%)")



x = weather_datas_df["lat"]
y = weather_datas_df["cloudiness"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.25
# The r-squared is: 0.06167767813928417
# The regression equation is: y = 0.7x + 62.86

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude (deg)")
plt.ylabel("Wind Speed (mph)")



x = weather_datan_df["lat"]
y = weather_datan_df["wind speed"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.09
# The r-squared is: 0.00864547287880449
# The regression equation is: y = 0.03x + 7.02

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude (deg)")
plt.ylabel("Wind Speed (mph)")



x = weather_datas_df["lat"]
y = weather_datas_df["wind speed"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is -0.23
# The r-squared is: 0.05216685225676436
# The regression equation is: y = -0.1x + 7.13
