# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Installing citipy module
#!pip install citipy
from citipy import citipy

# Dependencies
import pandas as pd
import numpy as np
import requests
import json

from scipy import stats
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Google API Key
from api_keys import g_key
from api_keys import weather_api_key
from itertools import product
from itertools import permutations
# print (weather_api_key)

import scipy.stats as st

# %% [markdown]
# ## Generate Cities List

# %%
#**********Need to fix the limit, gives more than 500 values***************

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1600)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1600)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 660

# %%
cities
# Out:
# ['cape town',
#  'atar',
#  'hobart',
#  'krasnoselkup',
#  'constitucion',
#  'arraial do cabo',
#  'albany',
#  'tambovka',
#  'kokopo',
#  'leningradskiy',
#  'punta arenas',
#  'cayenne',
#  'grand gaube',
#  'eureka',
#  'ushuaia',
#  'lorengau',
#  'yumen',
#  'mataura',
#  'bluff',
#  'busselton',
#  'verkhnyaya sinyachikha',
#  'bethel',
#  'marang',
#  'mecca',
#  'san cristobal',
#  'butaritari',
#  'norman wells',
#  'miyako',
#  'te anau',
#  'vao',
#  'kormend',
#  'narsaq',
#  'mehran',
#  'katsuura',
#  'camacha',
#  'alyangula',
#  'sibolga',
#  'santiago del estero',
#  'ironton',
#  'rikitea',
#  'agadir',
#  'port blair',
#  'yangjiang',
#  'buala',
#  'tahoua',
#  'kastamonu',
#  'jijiga',
#  'manggar',
#  'vaini',
#  'burica',
#  'barentsburg',
#  'pevek',
#  'kousseri',
#  'bambous virieux',
#  'saint-philippe',
#  'kaliua',
#  'barrow',
#  'hilo',
#  'xichang',
#  'clyde river',
#  'dwarka',
#  'maceio',
#  'tiksi',
#  'thompson',
#  'mikhaylovka',
#  'muisne',
#  'ostrovnoy',
#  'alofi',
#  'umm bab',
#  'ust-nera',
#  'avarua',
#  'port alfred',
#  'lebedyn',
#  'lavrentiya',
#  'taolanaro',
#  'hobyo',
#  'ponta do sol',
#  'tuktoyaktuk',
#  'borshchiv',
#  'victor harbor',
#  'victoria',
#  'atuona',
#  'nishihara',
#  'torbay',
#  'belaya gora',
#  'nikolskoye',
#  'bonthe',
#  'new norfolk',
#  'henties bay',
#  'port elizabeth',
#  'fortuna',
#  'galle',
#  'dikson',
#  'luganville',
#  'longyearbyen',
#  'lac du bonnet',
#  'morros',
#  'tasiilaq',
#  'carnarvon',
#  'rockport',
#  'escanaba',
#  'portland',
#  'east london',
#  'dovolnoye',
#  'agadez',
#  'georgetown',
#  'flin flon',
#  'hermanus',
#  'bulaevo',
#  'tarbes',
#  'chokurdakh',
#  'qaanaaq',
#  'hasaki',
#  'chapada dos guimaraes',
#  'ribeira grande',
#  'chuy',
#  'jamestown',
#  'esperance',
#  'castro',
#  'dillon',
#  'saskylakh',
#  'kenai',
#  'richards bay',
#  'cidreira',
#  'dharur',
#  'mahebourg',
#  'senanga',
#  'caravelas',
#  'kadoma',
#  'paamiut',
#  'sambava',
#  'illoqqortoormiut',
#  'komsomolskiy',
#  'pochutla',
#  'praya',
#  'muli',
#  'winnemucca',
#  'lodwar',
#  'samana',
#  'carbonia',
#  'sechura',
#  'khatanga',
#  'tawnat',
#  'razole',
#  'malartic',
#  'coron',
#  'satitoa',
#  'miyazu',
#  'cabo san lucas',
#  'spas-demensk',
#  'khandbari',
#  'sapele',
#  'kapaa',
#  'ngukurr',
#  'bengkulu',
#  'shaowu',
#  'viligili',
#  'tual',
#  'porto novo',
#  'maragogi',
#  'tema',
#  'griffith',
#  'araguacu',
#  'saint-augustin',
#  'umm kaddadah',
#  'saint-paul',
#  'rietavas',
#  'kaitangata',
#  'meulaboh',
#  'jatiroto',
#  'ewa beach',
#  'marawi',
#  'castle douglas',
#  'inhambane',
#  'hithadhoo',
#  'ayna',
#  'phan rang',
#  'otacilio costa',
#  'seljord',
#  'inverell',
#  'high level',
#  'ormara',
#  'haibowan',
#  'lagoa',
#  'ust-tsilma',
#  'stolin',
#  'saryozek',
#  'sobolevo',
#  'berlevag',
#  'mwinilunga',
#  'nelson bay',
#  'zonguldak',
#  'saint-pierre',
#  'biltine',
#  'lebu',
#  'bafra',
#  'tigil',
#  'muros',
#  'westport',
#  'fenoarivo',
#  'san patricio',
#  'waddan',
#  'tura',
#  'geraldton',
#  'axim',
#  'lichinga',
#  'gulu',
#  'bathsheba',
#  'cherskiy',
#  'arti',
#  'bredasdorp',
#  'mount pleasant',
#  'puerto ayora',
#  'mar del plata',
#  'taltal',
#  'nizhneyansk',
#  'kruisfontein',
#  'amderma',
#  'tinaquillo',
#  'santa isabel do rio negro',
#  'fairbanks',
#  'viedma',
#  'samusu',
#  'biu',
#  'dover',
#  'curup',
#  'necochea',
#  'walvis bay',
#  'san vicente',
#  'shingu',
#  'alexandria',
#  'maniitsoq',
#  'kapit',
#  'saldanha',
#  'grizanon',
#  'cabo rojo',
#  'labuhan',
#  'belushya guba',
#  'talesh',
#  'aguimes',
#  'jacareacanga',
#  'nome',
#  'noumea',
#  'yellowknife',
#  'khash',
#  'vostok',
#  'pechory',
#  'vila do maio',
#  'hermon',
#  'anadyr',
#  'bursa',
#  'mirnyy',
#  'aklavik',
#  'kamenka',
#  'coahuayana',
#  'sungairaya',
#  'svetlogorsk',
#  'saint george',
#  'vanavara',
#  'tuatapere',
#  'baruun-urt',
#  'namibe',
#  'isla mujeres',
#  'la ronge',
#  'pitimbu',
#  'montbrison',
#  'farmington',
#  'asau',
#  'vaitupu',
#  'quatre cocos',
#  'upernavik',
#  'belmopan',
#  'chicama',
#  'saint-francois',
#  'husavik',
#  'faanui',
#  'ilulissat',
#  'shchelyayur',
#  'omis',
#  'malanje',
#  'tsihombe',
#  'domoni',
#  'jibuti',
#  'vila',
#  'pacific grove',
#  'fairview',
#  'marivan',
#  'mogok',
#  'kansanshi',
#  'lompoc',
#  'yar-sale',
#  'lat yao',
#  'cockburn town',
#  'aswan',
#  'kodiak',
#  'aksu',
#  'zlynka',
#  'daosa',
#  'berwick',
#  'churapcha',
#  'cayeli',
#  'severo-kurilsk',
#  'itoman',
#  'xingyi',
#  'amahai',
#  'sao felix do xingu',
#  'kandi',
#  'kosh-agach',
#  'mayahi',
#  'poso',
#  'avera',
#  'provideniya',
#  'pericos',
#  'san nicolas',
#  'umtata',
#  'mulchen',
#  'sertania',
#  'makat',
#  'burkhala',
#  'kysyl-syr',
#  'skalistyy',
#  'gabu',
#  'vuktyl',
#  'isangel',
#  'hami',
#  'nanortalik',
#  'narok',
#  'iquique',
#  'arman',
#  'kahului',
#  'grand river south east',
#  'hit',
#  'chapais',
#  'road town',
#  'kupang',
#  'ballina',
#  'olafsvik',
#  'brigantine',
#  'palana',
#  'sitka',
#  'liverpool',
#  'raga',
#  'kingaroy',
#  'pinheiral',
#  'goteborg',
#  'la palma',
#  'belyy yar',
#  'goderich',
#  'talcahuano',
#  'tutoia',
#  'north battleford',
#  'meyungs',
#  'noyabrsk',
#  'vila velha',
#  'lolua',
#  'bubaque',
#  'hualmay',
#  'baykit',
#  'chala',
#  'muncie',
#  'bonavista',
#  'bantou',
#  'luderitz',
#  'yinchuan',
#  'rudnya',
#  'bati',
#  'qaqortoq',
#  'oistins',
#  'kiunga',
#  'lucea',
#  'college',
#  'grindavik',
#  'lumeje',
#  'iqaluit',
#  'jalu',
#  'shache',
#  'copiapo',
#  'kotar',
#  'barsovo',
#  'guaratinga',
#  'laguna',
#  'pangnirtung',
#  'yilan',
#  'okakarara',
#  'sola',
#  'beni',
#  'yerbogachen',
#  'puerto leguizamo',
#  'pontian kecil',
#  'biak',
#  'belle fourche',
#  'anchorage',
#  'vanimo',
#  'sorland',
#  'kitimat',
#  'nemuro',
#  'matara',
#  'airai',
#  'harper',
#  'turayf',
#  'moose factory',
#  'hirara',
#  'sao gabriel da cachoeira',
#  'cuxhaven',
#  'adrar',
#  'khandagayty',
#  'troitsko-pechorsk',
#  'manaus',
#  'cravo norte',
#  'newport',
#  'salisbury',
#  'codrington',
#  'buraydah',
#  'korla',
#  'el alto',
#  'zatoka',
#  'jagdalpur',
#  'chingola',
#  'tarragona',
#  'tan an',
#  'turan',
#  'hamilton',
#  'santander',
#  'dickson',
#  'fare',
#  'verkhniy baskunchak',
#  'grand centre',
#  'hambantota',
#  'sarangani',
#  'varsag',
#  'zhangye',
#  'selma',
#  'paradwip',
#  'southbridge',
#  'beclean',
#  'manokwari',
#  'udachnyy',
#  'granada',
#  'mys shmidta',
#  'samarai',
#  'port macquarie',
#  'broome',
#  'chicaman',
#  'nieuw amsterdam',
#  'dondo',
#  'ulladulla',
#  'imeni poliny osipenko',
#  'mut',
#  'goure',
#  'kamal',
#  'khandyga',
#  'loandjili',
#  'pisco',
#  'ixtapa',
#  'tavrichanka',
#  'douglas',
#  'gushikawa',
#  'ponta delgada',
#  'half moon bay',
#  'faya',
#  'puerto varas',
#  'los llanos de aridane',
#  'mehamn',
#  'piranhas',
#  'sentyabrskiy',
#  'timizart',
#  'jimalalud',
#  'mount gambier',
#  'orlik',
#  'saint paul',
#  'boca do acre',
#  'tarpon springs',
#  'santa marta',
#  'lozuvatka',
#  'adamas',
#  'dawei',
#  'gamba',
#  'kendari',
#  'grand-santi',
#  'talnakh',
#  'plymouth',
#  'santa cruz de la palma',
#  'natal',
#  'yantal',
#  'faridan',
#  'alta floresta',
#  'melo',
#  'haines junction',
#  'bantul',
#  'palmer',
#  'ishigaki',
#  'tumannyy',
#  'dunedin',
#  'reconquista',
#  'marcona',
#  'abrau-dyurso',
#  'valdepenas',
#  'tafresh',
#  'comodoro rivadavia',
#  'san sebastian',
#  'nalut',
#  'mlonggo',
#  'rumes',
#  'saint-joseph',
#  'sao joao da barra',
#  'polyarnyye zori',
#  'kabanjahe',
#  'sassandra',
#  'launceston',
#  'san marcos',
#  'buin',
#  'hofn',
#  'san jose',
#  'ancud',
#  'beloha',
#  'san jose de gracia',
#  'yershichi',
#  'kavaratti',
#  'san luis',
#  'mount isa',
#  'mezen',
#  'port hueneme',
#  'khon buri',
#  'dumfries',
#  'ullapool',
#  'werda',
#  'saleaula',
#  'kholbon',
#  'manpur',
#  'manzanillo',
#  'kingman',
#  'lanzhou',
#  'solovetskiy',
#  'mahibadhoo',
#  'wicklow',
#  'ambon',
#  'trenggalek',
#  'dingle',
#  'zuwarah',
#  'honiara',
#  'praia da vitoria',
#  'ahipara',
#  'makakilo city',
#  'bluefield',
#  'kutum',
#  'santa cruz de tenerife',
#  'ternate',
#  'san ramon',
#  'vytegra',
#  'cap malheureux',
#  'abu samrah',
#  'koslan',
#  'kalmunai',
#  'dubbo',
#  'careiro da varzea',
#  'toshkivka',
#  'teya',
#  'attawapiskat',
#  'gimli',
#  'zhanaozen',
#  'yabrud',
#  'aden',
#  'taoudenni',
#  'klaksvik',
#  'sorvag',
#  'atlantic city',
#  'tucuman',
#  'tiarei',
#  'zyryanka',
#  'bintulu',
#  'wynyard',
#  'santiago de chuco',
#  'luwuk',
#  'lagos',
#  'port keats',
#  'ahuimanu',
#  'novikovo',
#  'bahia honda',
#  'yalvac',
#  'champerico',
#  'boguchany',
#  'siraha',
#  'dossor',
#  'gbarnga',
#  'stromness',
#  'beringovskiy',
#  'caucaia',
#  'gidole',
#  'yangambi',
#  'fantino',
#  'noshiro',
#  'aljezur',
#  'souillac',
#  'treinta y tres',
#  'etchoropo',
#  'nova olimpia',
#  'miri',
#  'vardo',
#  'sheridan',
#  'bundaberg',
#  'tiznit',
#  'guajara-mirim',
#  'riyadh',
#  'metro',
#  'sembe',
#  'nago',
#  'unidad',
#  'kikwit',
#  'erenhot',
#  'porto walter',
#  'linxia',
#  'morozovsk',
#  'alibag',
#  'masterton',
#  'srivardhan',
#  'chokwe',
#  'sabha',
#  'ginir',
#  'moerai',
#  'falam',
#  'kamoke',
#  'kavieng',
#  'lasa',
#  'matay',
#  'namatanai',
#  'royan',
#  'kortkeros',
#  'utiroa',
#  'guerrero negro',
#  'morgan city',
#  'awbari',
#  'yaviza',
#  'upata',
#  'yarada',
#  'pacora',
#  'bolshegrivskoye',
#  'luanda',
#  'valleyview',
#  'karpuninskiy',
#  'nchelenge',
#  'eyl',
#  'zelenoborskiy',
#  'kokkola',
#  'bairiki',
#  'jasper',
#  'perth',
#  'barkhan',
#  'salalah',
#  'nantucket',
#  'parainen',
#  'ottawa',
#  'joshimath',
#  'olginskaya',
#  'sorong',
#  'tobe',
#  'kelvington',
#  'cam ranh',
#  'pandan',
#  'angoche',
#  'yaan']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=6bbc6f9aa8c2d78e5b37d1a8c9cd4e68&units=imperial&q='

# %%
# This creates a loop that pulls out the weather data for each city name in the list.
weather=np.array([])
data = ()

# set up lists to hold response info
lat = []
temp = []
cloudiness = []
country = []
humidity =[]
lat =[]
lng = []
temp = []
wind_speed = []
city_name = []
index_counter = 0
set_counter = 1


for index, city in enumerate(cities, start =1):
        
    try:
        response = requests.get(query_url + city).json()
        
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        
        if index_counter >49:
            index_counter = 0
            set_counter = set_counter +1
            
        else:
            index_counter = index_counter + 1
            
        print(f"Processing city {index_counter} of Set {set_counter} : {city}")   
    
    except (KeyError, IndexError):
        print ("Error - skip.")

print("Done")
# Out:
# Processing city 1 of Set 1 : cape town
# Processing city 2 of Set 1 : atar
# Processing city 3 of Set 1 : hobart
# Processing city 4 of Set 1 : krasnoselkup
# Processing city 5 of Set 1 : constitucion
# Processing city 6 of Set 1 : arraial do cabo
# Processing city 7 of Set 1 : albany
# Processing city 8 of Set 1 : tambovka
# Processing city 9 of Set 1 : kokopo
# Processing city 10 of Set 1 : leningradskiy
# Processing city 11 of Set 1 : punta arenas
# Processing city 12 of Set 1 : cayenne
# Processing city 13 of Set 1 : grand gaube
# Processing city 14 of Set 1 : eureka
# Processing city 15 of Set 1 : ushuaia
# Processing city 16 of Set 1 : lorengau
# Processing city 17 of Set 1 : yumen
# Processing city 18 of Set 1 : mataura
# Processing city 19 of Set 1 : bluff
# Processing city 20 of Set 1 : busselton
# Processing city 21 of Set 1 : verkhnyaya sinyachikha
# Processing city 22 of Set 1 : bethel
# Processing city 23 of Set 1 : marang
# Processing city 24 of Set 1 : mecca
# Processing city 25 of Set 1 : san cristobal
# Processing city 26 of Set 1 : butaritari
# Processing city 27 of Set 1 : norman wells
# Processing city 28 of Set 1 : miyako
# Processing city 29 of Set 1 : te anau
# Processing city 30 of Set 1 : vao
# Processing city 31 of Set 1 : kormend
# Processing city 32 of Set 1 : narsaq
# Processing city 33 of Set 1 : mehran
# Processing city 34 of Set 1 : katsuura
# Processing city 35 of Set 1 : camacha
# Processing city 36 of Set 1 : alyangula
# Processing city 37 of Set 1 : sibolga
# Processing city 38 of Set 1 : santiago del estero
# Processing city 39 of Set 1 : ironton
# Processing city 40 of Set 1 : rikitea
# Processing city 41 of Set 1 : agadir
# Processing city 42 of Set 1 : port blair
# Processing city 43 of Set 1 : yangjiang
# Processing city 44 of Set 1 : buala
# Processing city 45 of Set 1 : tahoua
# Processing city 46 of Set 1 : kastamonu
# Processing city 47 of Set 1 : jijiga
# Processing city 48 of Set 1 : manggar
# Processing city 49 of Set 1 : vaini
# Error - skip.
# Error - skip.
# Processing city 50 of Set 1 : pevek
# Processing city 47 of Set 4 : arti
# Processing city 48 of Set 4 : bredasdorp
# Processing city 49 of Set 4 : mount pleasant
# Processing city 50 of Set 4 : puerto ayora
# Processing city 0 of Set 5 : mar del plata
# Processing city 1 of Set 5 : taltal
# Error - skip.
# Processing city 2 of Set 5 : kruisfontein
# Error - skip.
# Processing city 3 of Set 5 : tinaquillo
# Processing city 4 of Set 5 : santa isabel do rio negro
# Processing city 5 of Set 5 : fairbanks
# Processing city 6 of Set 5 : viedma
# Error - skip.
# Processing city 7 of Set 5 : biu
# Processing city 8 of Set 5 : dover
# Processing city 9 of Set 5 : curup
# Processing city 10 of Set 5 : necochea
# Processing city 11 of Set 5 : walvis bay
# Processing city 12 of Set 5 : san vicente
# Processing city 13 of Set 5 : shingu
# Processing city 14 of Set 5 : alexandria
# Processing city 15 of Set 5 : maniitsoq
# Processing city 16 of Set 5 : kapit
# Processing city 17 of Set 5 : saldanha
# Processing city 18 of Set 5 : grizanon
# Processing city 19 of Set 5 : cabo rojo
# Processing city 20 of Set 5 : labuhan
# Error - skip.
# Error - skip.
# Processing city 21 of Set 5 : aguimes
# Processing city 22 of Set 5 : jacareacanga
# Processing city 23 of Set 5 : nome
# Processing city 24 of Set 5 : noumea
# Processing city 25 of Set 5 : yellowknife
# Processing city 26 of Set 5 : khash
# Processing city 27 of Set 5 : vostok
# Processing city 28 of Set 5 : pechory
# Processing city 29 of Set 5 : vila do maio
# Processing city 30 of Set 5 : hermon
# Processing city 31 of Set 5 : anadyr
# Processing city 32 of Set 5 : bursa
# Processing city 33 of Set 5 : mirnyy
# Processing city 34 of Set 5 : aklavik
# Processing city 35 of Set 5 : kamenka
# Processing city 36 of Set 5 : coahuayana
# Processing city 37 of Set 5 : sungairaya
# Processing city 38 of Set 5 : svetlogorsk
# Processing city 39 of Set 5 : saint george
# Processing city 40 of Set 5 : vanavara
# Processing city 41 of Set 5 : tuatapere
# Processing city 42 of Set 5 : baruun-urt
# Processing city 43 of Set 5 : namibe
# Processing city 44 of Set 5 : isla mujeres
# Processing city 45 of Set 5 : la ronge
# Processing city 46 of Set 5 : pitimbu
# Processing city 47 of Set 5 : montbrison
# Processing city 48 of Set 5 : farmington
# Processing city 49 of Set 5 : asau
# Error - skip.
# Processing city 50 of Set 5 : quatre cocos
# Processing city 0 of Set 6 : upernavik
# Processing city 1 of Set 6 : belmopan
# Processing city 2 of Set 6 : chicama
# Processing city 3 of Set 6 : saint-francois
# Processing city 4 of Set 6 : husavik
# Processing city 5 of Set 6 : faanui
# Processing city 6 of Set 6 : ilulissat
# Error - skip.
# Processing city 7 of Set 6 : omis
# Processing city 8 of Set 6 : malanje
# Error - skip.
# Processing city 9 of Set 6 : domoni
# Processing city 10 of Set 6 : jibuti
# Processing city 11 of Set 6 : vila
# Processing city 12 of Set 6 : pacific grove
# Processing city 13 of Set 6 : fairview
# Processing city 14 of Set 6 : marivan
# Processing city 15 of Set 6 : mogok
# Processing city 16 of Set 6 : kansanshi
# Processing city 17 of Set 6 : lompoc
# Processing city 18 of Set 6 : yar-sale
# Processing city 12 of Set 12 : porto walter
# Processing city 13 of Set 12 : linxia
# Processing city 14 of Set 12 : morozovsk
# Processing city 15 of Set 12 : alibag
# Processing city 16 of Set 12 : masterton
# Processing city 17 of Set 12 : srivardhan
# Processing city 18 of Set 12 : chokwe
# Processing city 19 of Set 12 : sabha
# Processing city 20 of Set 12 : ginir
# Processing city 21 of Set 12 : moerai
# Processing city 22 of Set 12 : falam
# Processing city 23 of Set 12 : kamoke
# Processing city 24 of Set 12 : kavieng
# Processing city 25 of Set 12 : lasa
# Processing city 26 of Set 12 : matay
# Processing city 27 of Set 12 : namatanai
# Processing city 28 of Set 12 : royan
# Processing city 29 of Set 12 : kortkeros
# Error - skip.
# Processing city 30 of Set 12 : guerrero negro
# Processing city 31 of Set 12 : morgan city
# Processing city 32 of Set 12 : awbari
# Processing city 33 of Set 12 : yaviza
# Processing city 34 of Set 12 : upata
# Processing city 35 of Set 12 : yarada
# Processing city 36 of Set 12 : pacora
# Error - skip.
# Processing city 37 of Set 12 : luanda
# Processing city 38 of Set 12 : valleyview
# Error - skip.
# Processing city 39 of Set 12 : nchelenge
# Processing city 40 of Set 12 : eyl
# Processing city 41 of Set 12 : zelenoborskiy
# Processing city 42 of Set 12 : kokkola
# Processing city 43 of Set 12 : bairiki
# Processing city 44 of Set 12 : jasper
# Processing city 45 of Set 12 : perth
# Processing city 46 of Set 12 : barkhan
# Processing city 47 of Set 12 : salalah
# Processing city 48 of Set 12 : nantucket
# Processing city 49 of Set 12 : parainen
# Processing city 50 of Set 12 : ottawa
# Processing city 0 of Set 13 : joshimath
# Processing city 1 of Set 13 : olginskaya
# Processing city 2 of Set 13 : sorong
# Processing city 3 of Set 13 : tobe
# Processing city 4 of Set 13 : kelvington
# Processing city 5 of Set 13 : cam ranh
# Processing city 6 of Set 13 : pandan
# Processing city 7 of Set 13 : angoche
# Processing city 8 of Set 13 : yaan
# Done

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data2_df = pd.DataFrame({
    "city": city_name,
    "country": country,
    "lat": lat,
    "temp": temp,
    "humidity": humidity,
    "cloudiness": cloudiness,
    "wind speed": wind_speed

})
   
weather_data2.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0bbe4c4ad7c2> in <module>
#      10 })
#      11
# ---> 12 weather_data2.count()
#
# NameError: name 'weather_data2' is not defined

# %%
weather_data2_df
# Out:
#               city country    lat   temp  humidity  cloudiness  wind speed
# 0        Cape Town      ZA -33.93  56.53        87          28        2.24
# 1             Atar      MR  20.52  90.12        36           4       11.41
# 2           Hobart      AU -42.88  53.85        50          20       11.41
# 3    Krasnosel'kup      RU  65.70  33.33        98          98        8.95
# 4     Constitución      CL -35.33  57.40        70           0       14.29
# ..             ...     ...    ...    ...       ...         ...         ...
# 615     Kelvington      CA  52.17  45.63        55          49       19.69
# 616       Cam Ranh      VN  11.92  80.60        88          75        3.36
# 617         Pandan      PH  14.05  82.09        82          96        6.53
# 618        Angoche      MZ -16.23  76.33        81         100       10.36
# 619           Yaan      NG   7.38  75.02        93          17        5.73
#
# [620 rows x 7 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# print(weather_data2_df[(city_name)].where(weather_data2_df[(humidity)] > 100))

h_humid_df = weather_data2_df[weather_data2_df['humidity'] > (100)]
h_humid_df
# Out:
# Empty DataFrame
# Columns: [city, country, lat, temp, humidity, cloudiness, wind speed]
# Index: []

# %%
# There are no cities with humidity greater than 100**


#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.title("Latitude vs. Temperature Plot")
plt.xlabel("Latitude (deg)")
plt.ylabel("Temperature (F)")

plt.scatter(lat,temp)
plt.show(lat,temp)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.title("Latitude vs. Humidity Plot")
plt.xlabel("Latitude (deg)")
plt.ylabel("Humidity (%)")

plt.scatter(lat,humidity)
plt.show(lat,humidity)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.title("Latitude vs. Cloudiness Plot")
plt.xlabel("Latitude (deg)")
plt.ylabel("Cloudiness (%)")

plt.scatter(lat,cloudiness)
plt.show(lat,cloudiness)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.title("Latitude vs. Wind Speed Plot")
plt.xlabel("Latitude (deg)")
plt.ylabel("Wind Speed (mph)")

plt.scatter(lat,wind_speed)
plt.show(lat,wind_speed)

# %% [markdown]
# ## Linear Regression

# %%
north = weather_data2_df['lat']>0
print(north.head())

south = weather_data2_df['lat']<0
print(south.head())
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: lat, dtype: bool
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: lat, dtype: bool

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
weather_datan_df = weather_data2_df[north]
print(weather_datan_df.tail())

weather_datas_df = weather_data2_df[south]
print(weather_datas_df.tail())
# Out:
#            city country    lat   temp  humidity  cloudiness  wind speed
# 614        Tobe      JP  33.74  68.00        77          75        9.17
# 615  Kelvington      CA  52.17  45.63        55          49       19.69
# 616    Cam Ranh      VN  11.92  80.60        88          75        3.36
# 617      Pandan      PH  14.05  82.09        82          96        6.53
# 619        Yaan      NG   7.38  75.02        93          17        5.73
#           city country    lat   temp  humidity  cloudiness  wind speed
# 597     Luanda      AO  -8.84  73.40        83          40        8.05
# 599  Nchelenge      ZM  -9.35  71.89        78          66        7.47
# 605      Perth      AU -31.93  63.05        63           9        1.12
# 613     Sorong      ID  -0.88  79.09        85          83        7.07
# 618    Angoche      MZ -16.23  76.33        81         100       10.36

# %%
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")



x = weather_datan_df["lat"]
y = weather_datan_df["temp"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Temp Max (F)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is -0.84
# The r-squared is: 0.706594273147819
# The regression equation is: y = -0.81x + 89.75

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")



x = weather_datas_df["lat"]
y = weather_datas_df["temp"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Temp Max (F)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.75
# The r-squared is: 0.5561270214405863
# The regression equation is: y = 0.56x + 80.69

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")



x = weather_datan_df["lat"]
y = weather_datan_df["humidity"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.11
# The r-squared is: 0.012288323264194507
# The regression equation is: y = 0.12x + 68.98

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")



x = weather_datas_df["lat"]
y = weather_datas_df["humidity"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.23
# The r-squared is: 0.05152272891570877
# The regression equation is: y = 0.28x + 78.61

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude (deg)")
plt.ylabel("Cloudiness (%)")



x = weather_datan_df["lat"]
y = weather_datan_df["cloudiness"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.2
# The r-squared is: 0.04163617792326685
# The regression equation is: y = 0.39x + 41.94

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude (deg)")
plt.ylabel("Cloudiness (%)")



x = weather_datas_df["lat"]
y = weather_datas_df["cloudiness"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.29
# The r-squared is: 0.08485821760058065
# The regression equation is: y = 0.77x + 64.04

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude (deg)")
plt.ylabel("Wind Speed (mph)")



x = weather_datan_df["lat"]
y = weather_datan_df["wind speed"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is 0.17
# The r-squared is: 0.02745119591042641
# The regression equation is: y = 0.04x + 6.13

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude (deg)")
plt.ylabel("Wind Speed (mph)")



x = weather_datas_df["lat"]
y = weather_datas_df["wind speed"]

correlation = st.pearsonr(x,y)
print(f"The correlation between both factors is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude (deg)')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
print(f"The regression equation is: {line_eq}")
plt.show()
# Out:
# The correlation between both factors is -0.22
# The r-squared is: 0.048748052145171146
# The regression equation is: y = -0.09x + 5.89
